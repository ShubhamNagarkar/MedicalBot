# %% [markdown]
# # Dataset Analysis
#
#  This notebook covers basic data analysis, going through the dataset columns, finding out inconsistencies, etc.
#
#  ##### Any AI based assistance, code completion was not used to solve this problem.

# %%
import re
import json
import spacy
import pandas as pd
from collections import defaultdict, Counter
from utils import write_json

# %%
dataset = pd.read_csv('./data/medical_dataset.csv')
print('Total dataset size: ',len(dataset))
# Out:
# Total dataset size:  16406

# %%
dataset.head(15)
# Out:
#                                              question  \
# 0                            What is (are) Glaucoma ?
# 1                            What is (are) Glaucoma ?
# 2                            What is (are) Glaucoma ?
# 3                      Who is at risk for Glaucoma? ?
# 4                           How to prevent Glaucoma ?
# 5                 What are the symptoms of Glaucoma ?
# 6              What are the treatments for Glaucoma ?
# 7   what research (or clinical trials) is being do...
# 8                      Who is at risk for Glaucoma? ?
# 9                            What is (are) Glaucoma ?
# 10                What is (are) High Blood Pressure ?
# 11                  What causes High Blood Pressure ?
# 12          Who is at risk for High Blood Pressure? ?
# 13               How to prevent High Blood Pressure ?
# 14     What are the symptoms of High Blood Pressure ?
#
#                                                answer
# 0   Glaucoma is a group of diseases that can damag...
# 1   The optic nerve is a bundle of more than 1 mil...
# 2   Open-angle glaucoma is the most common form of...
# 3   Anyone can develop glaucoma. Some people are a...
# 4   At this time, we do not know how to prevent gl...
# 5   At first, open-angle glaucoma has no symptoms....
# 6   Yes. Immediate treatment for early stage, open...
# 7   Through studies in the laboratory and with pat...
# 8   Encourage them to have a comprehensive dilated...
# 9   National Eye Institute  National Institutes of...
# 10  High blood pressure is a common disease in whi...
# 11  Changes in Body Functions Researchers continue...
# 12  Not a Normal Part of Aging Nearly 1 in 3 Ameri...
# 13  Steps You Can Take You can take steps to preve...
# 14  High blood pressure is often called the "silen...

# %%
# check for nan values
print(dataset.isna().any(),dataset['answer'].isna().sum())
# Out:
# question    False
# answer       True
# dtype: bool 5

# %%
rows_with_nan = dataset[dataset.isna().any(axis=1)]
rows_with_nan
# Out:
#                                                question answer
# 3587                     What is (are) HELLP syndrome ?    NaN
# 3836  What is (are) X-linked lymphoproliferative syn...    NaN
# 4196            What is (are) Familial HDL deficiency ?    NaN
# 4429  What is (are) Emery-Dreifuss muscular dystroph...    NaN
# 6689  What is (are) Emery-Dreifuss muscular dystroph...    NaN

# %%
# remove rows with NaN as there are just 5 rows.
dataset.dropna(inplace=True)
dataset.shape
# Out:
# (16401, 2)

# %% [markdown]
# # Question: What is (are) Glaucoma ?
#
# Understanding how the answers are structure for a sample question

# %%
dataset.iloc[9]['answer']
# Out:
# 'National Eye Institute  National Institutes of Health  2020 Vision Place  Bethesda, MD 20892-3655  301-496-5248  E-mail: 2020@nei.nih.gov  www.nei.nih.gov The Glaucoma Foundation  80 Maiden Lane, Suite 700  New York, NY 10038  212-285-0080 Glaucoma Research Foundation  251 Post Street, Suite 600  San Francisco, CA 94108  1-800-826-6693'

# %%
dataset.iloc[1]['answer']
# Out:
# 'The optic nerve is a bundle of more than 1 million nerve fibers. It connects the retina to the brain.'

# %%
dataset.iloc[2]['answer']
# Out:
# 'Open-angle glaucoma is the most common form of glaucoma. In the normal eye, the clear fluid leaves the anterior chamber at the open angle where the cornea and iris meet. When the fluid reaches the angle, it flows through a spongy meshwork, like a drain, and leaves the eye. Sometimes, when the fluid reaches the angle, it passes too slowly through the meshwork drain, causing the pressure inside the eye to build. If the pressure damages the optic nerve, open-angle glaucoma -- and vision loss -- may result.'

# %%
dataset.iloc[0]['answer']
# Out:
# "Glaucoma is a group of diseases that can damage the eye's optic nerve and result in vision loss and blindness. The most common form of the disease is open-angle glaucoma. With early treatment, you can often protect your eyes against serious vision loss. (Watch the video to learn more about glaucoma. To enlarge the video, click the brackets in the lower right-hand corner. To reduce the video, press the Escape (Esc) button on your keyboard.)  See this graphic for a quick overview of glaucoma, including how many people it affects, whos at risk, what to do if you have it, and how to learn more.  See a glossary of glaucoma terms."

# %% [markdown]
# # Question to Answers Counter

# %%
# Counts number of answers per question before cleaning.

question_to_answers = defaultdict(list)

for row, text in dataset.iterrows():
    q = text['question']
    a = text['answer']
    question_to_answers[q].append(a)

question_to_answers_cnt = Counter(dataset['question'].values)
    
print('Total unique Questions: ',len(question_to_answers))
# Out:
# Total unique Questions:  14976

# %%
question_to_answers_cnt
# Out:
# Counter({'What causes Causes of Diabetes ?': 20,
#          'What is (are) High Blood Cholesterol ?': 19,
#          'What is (are) Medicare and Continuing Care ?': 14,
#          'What is (are) Stroke ?': 13,
#          'What is (are) Skin Cancer ?': 13,
#          'What is (are) Breast Cancer ?': 12,
#          'What are the treatments for Breast Cancer ?': 12,
#          'What is (are) Colorectal Cancer ?': 12,
#          'What is (are) Kidney Failure: Eat Right to Feel Right on Hemodialysis ?': 12,
#          'What is (are) High Blood Pressure ?': 11,
#          "What is (are) Parkinson's Disease ?": 11,
#          'What are the treatments for Prostate Cancer ?': 10,
#          'What is (are) Leukemia ?': 10,
#          'What is (are) Nutrition for Advanced Chronic Kidney Disease in Adults ?': 10,
#          'What is (are) Prostate Cancer ?': 9,
#          'Who is at risk for Prostate Cancer? ?': 9,
#          'What is (are) Age-related Macular Degeneration ?': 9,
#          'Who is at risk for Breast Cancer? ?': 9,
#          'What is (are) Diabetes ?': 8,
#          'What is (are) Dry Mouth ?': 8,
#          "What is (are) Alzheimer's Disease ?": 8,
#          'What is (are) Lung Cancer ?': 8,
#          'What are the treatments for Lung Cancer ?': 7,
#          'What is (are) Psoriasis ?': 7,
#          'What are the treatments for Prescription and Illicit Drug Abuse ?': 7,
#          'What is (are) Cataract ?': 7,
#          'What is (are) Creating a Family Health History ?': 7,
#          'What is (are) Heart Attack ?': 7,
#          'What is (are) Anxiety Disorders ?': 6,
#          'What is (are) Knee Replacement ?': 6,
#          'What is (are) Osteoporosis ?': 6,
#          'Who is at risk for Osteoporosis? ?': 6,
#          "what research (or clinical trials) is being done for Alzheimer's Disease ?": 6,
#          'What is (are) Diabetic Retinopathy ?': 6,
#          'Who is at risk for Colorectal Cancer? ?': 6,
#          'Who is at risk for Lung Cancer? ?': 6,
#          'What are the treatments for Psoriasis ?': 6,
#          'What are the treatments for Surviving Cancer ?': 6,
#          "What is (are) Alzheimer's Caregiving ?": 6,
#          'What are the treatments for Gum (Periodontal) Disease ?': 6,
#          'What is (are) Heart Failure ?': 6,
#          'What are the treatments for Heart Failure ?': 6,
#          'What is (are) Financial Help for Diabetes Care ?': 6,
#          'What is (are) Diabetes, Heart Disease, and Stroke ?': 6,
#          'What is (are) What I need to know about Kidney Failure and How Its Treated ?': 6,
#          'What are the treatments for National Hormone and Pituitary Program (NHPP): Information for People Treated with Pituitary Human Growth Hormone (Comprehensive Report) ?': 6,
#          'What is (are) Diabetic Neuropathies: The Nerve Damage of Diabetes ?': 6,
#          'What is (are) Glaucoma ?': 5,
#          'What are the treatments for Alcohol Use and Older Adults ?': 5,
#          'What are the treatments for Osteoarthritis ?': 5,
#          'What is (are) Balance Problems ?': 5,
#          'What is (are) Kidney Disease ?': 5,
#          'What are the treatments for Kidney Disease ?': 5,
#          "How to prevent Alzheimer's Disease ?": 5,
#          'What are the treatments for Diabetic Retinopathy ?': 5,
#          'what research (or clinical trials) is being done for Breast Cancer ?': 5,
#          'What are the treatments for Leukemia ?': 5,
#          'What are the treatments for Stroke ?': 5,
#          'Who is at risk for Cataract? ?': 5,
#          'What is (are) Shingles ?': 5,
#          'What are the treatments for Heart Attack ?': 5,
#          'Who is at risk for Skin Cancer? ?': 5,
#          'What is (are) Surviving Cancer ?': 5,
#          'What is (are) Dry Eye ?': 5,
#          "What is (are) Kidney Failure: Choosing a Treatment That's Right for You ?": 5,
#          'How to prevent High Blood Pressure ?': 4,
#          'What are the treatments for High Blood Pressure ?': 4,
#          'What is (are) Alcohol Use and Older Adults ?': 4,
#          'What are the treatments for Diabetes ?': 4,
#          'What is (are) Quitting Smoking for Older Adults ?': 4,
#          'What are the symptoms of Prostate Cancer ?': 4,
#          'What causes Dry Mouth ?': 4,
#          "What are the treatments for Alzheimer's Disease ?": 4,
#          'What is (are) Rheumatoid Arthritis ?': 4,
#          'What is (are) COPD ?': 4,
#          'What is (are) Depression ?': 4,
#          'What are the symptoms of Breast Cancer ?': 4,
#          'What are the treatments for Colorectal Cancer ?': 4,
#          'What is (are) Urinary Incontinence ?': 4,
#          'Who is at risk for Stroke? ?': 4,
#          'What is (are) Prescription and Illicit Drug Abuse ?': 4,
#          'What are the symptoms of Heart Attack ?': 4,
#          'Who is at risk for Heart Attack? ?': 4,
#          'What are the treatments for Skin Cancer ?': 4,
#          'what research (or clinical trials) is being done for Skin Cancer ?': 4,
#          'What is (are) Gout ?': 4,
#          'What is (are) Gum (Periodontal) Disease ?': 4,
#          'How to diagnose Heart Failure ?': 4,
#          'What is (are) Neuroblastoma ?': 4,
#          'What is (are) Gallstones ?': 4,
#          'What is (are) Lactose Intolerance ?': 4,
#          'What is (are) Wilson Disease ?': 4,
#          'What is (are) Hemochromatosis ?': 4,
#          'What is (are) Porphyria ?': 4,
#          'What is (are) Causes of Diabetes ?': 4,
#          'What to do for Causes of Diabetes ?': 4,
#          'What is (are) Urinary Incontinence in Men ?': 4,
#          'What is (are) Autoimmune Hepatitis ?': 4,
#          'What is (are) Short Bowel Syndrome ?': 4,
#          'What is (are) What I need to know about Hepatitis B ?': 4,
#          'What is (are) Insulin Resistance and Prediabetes ?': 4,
#          'What is (are) Amyloidosis and Kidney Disease ?': 4,
#          'What is (are) Renal Tubular Acidosis ?': 4,
#          'What is (are) Nutrition for Early Chronic Kidney Disease in Adults ?': 4,
#          'What is (are) What I need to know about Hepatitis C ?': 4,
#          "What is (are) Paget's Disease of Bone ?": 3,
#          "What are the treatments for Paget's Disease of Bone ?": 3,
#          'What is (are) Urinary Tract Infections ?': 3,
#          'What is (are) Osteoarthritis ?': 3,
#          'What is (are) Problems with Taste ?': 3,
#          'What causes Problems with Taste ?': 3,
#          'How to prevent Diabetes ?': 3,
#          'What are the complications of Knee Replacement ?': 3,
#          'How to prevent Balance Problems ?': 3,
#          'What are the treatments for Balance Problems ?': 3,
#          'what research (or clinical trials) is being done for Prostate Cancer ?': 3,
#          'How to diagnose Prostate Cancer ?': 3,
#          'What are the treatments for Dry Mouth ?': 3,
#          'What are the treatments for Osteoporosis ?': 3,
#          "How to diagnose Alzheimer's Disease ?": 3,
#          'What are the treatments for Rheumatoid Arthritis ?': 3,
#          'How to prevent Hearing Loss ?': 3,
#          'What is (are) Low Vision ?': 3,
#          'What causes COPD ?': 3,
#          'What are the symptoms of COPD ?': 3,
#          'What are the symptoms of Age-related Macular Degeneration ?': 3,
#          'What are the treatments for Age-related Macular Degeneration ?': 3,
#          'What are the symptoms of Diabetic Retinopathy ?': 3,
#          'What are the treatments for Depression ?': 3,
#          'What is (are) Problems with Smell ?': 3,
#          'What causes Problems with Smell ?': 3,
#          'How to diagnose Breast Cancer ?': 3,
#          'How to prevent Breast Cancer ?': 3,
#          "What are the symptoms of Parkinson's Disease ?": 3,
#          "What are the treatments for Parkinson's Disease ?": 3,
#          "what research (or clinical trials) is being done for Parkinson's Disease ?": 3,
#          'What causes Lung Cancer ?': 3,
#          'What are the treatments for Urinary Incontinence ?': 3,
#          'What are the symptoms of Stroke ?': 3,
#          'How to prevent Stroke ?': 3,
#          'what research (or clinical trials) is being done for Stroke ?': 3,
#          'What are the treatments for High Blood Cholesterol ?': 3,
#          'What is (are) Peripheral Arterial Disease (P.A.D.) ?': 3,
#          'What are the symptoms of Shingles ?': 3,
#          'What are the treatments for Shingles ?': 3,
#          'What causes Heart Attack ?': 3,
#          'How to diagnose Heart Attack ?': 3,
#          'Who is at risk for Gout? ?': 3,
#          'What causes Dry Eye ?': 3,
#          'What causes Gum (Periodontal) Disease ?': 3,
#          'What causes Heart Failure ?': 3,
#          'Who is at risk for Heart Failure? ?': 3,
#          'What are the symptoms of Heart Failure ?': 3,
#          'Who is at risk for Testicular Cancer? ?': 3,
#          'Who is at risk for Oral Cavity and Oropharyngeal Cancer? ?': 3,
#          'What is (are) Endometrial Cancer ?': 3,
#          'Who is at risk for Endometrial Cancer? ?': 3,
#          'What is (are) Pituitary Tumors ?': 3,
#          'What is (are) Ulcerative Colitis ?': 3,
#          'What is (are) Hemophilia ?': 3,
#          'What is (are) Asthma ?': 3,
#          'What is (are) Hypoglycemia ?': 3,
#          "What is (are) Crohn's Disease ?": 3,
#          'What is (are) Neurofibromatosis ?': 3,
#          'What is (are) Sarcoidosis ?': 3,
#          'What is (are) Sleep Apnea ?': 3,
#          'What is (are) Hyperthyroidism ?': 3,
#          'What is (are) Hypothyroidism ?': 3,
#          "What is (are) Cushing's Syndrome ?": 3,
#          'What is (are) Narcolepsy ?': 3,
#          'What are the treatments for Narcolepsy ?': 3,
#          'What are the symptoms of Hemochromatosis ?': 3,
#          'What causes Hemochromatosis ?': 3,
#          'What is the outlook for Electrocardiogram ?': 3,
#          'What causes Gas in the Digestive Tract ?': 3,
#          "What are the treatments for Adrenal Insufficiency and Addison's Disease ?": 3,
#          'What is (are) Monogenic Forms of Diabetes: Neonatal Diabetes Mellitus and Maturity-onset Diabetes of the Young ?': 3,
#          'What is (are) Kidney Stones in Children ?': 3,
#          'What causes What I need to know about Erectile Dysfunction ?': 3,
#          'What are the treatments for What I need to know about Diverticular Disease ?': 3,
#          'What is (are) Prevent diabetes problems: Keep your kidneys healthy ?': 3,
#          "What are the treatments for Kidney Failure: Choosing a Treatment That's Right for You ?": 3,
#          'What is (are) What I need to know about Kidney Stones ?': 3,
#          'What is (are) Kidney Stones in Adults ?': 3,
#          'What causes What I need to know about Gas ?': 3,
#          'What are the treatments for Diabetes, Heart Disease, and Stroke ?': 3,
#          'What are the treatments for Acromegaly ?': 3,
#          'What is (are) Primary Hyperparathyroidism ?': 3,
#          'What is (are) Fecal Incontinence ?': 3,
#          'What is (are) Polycystic Kidney Disease ?': 3,
#          'What are the treatments for What I need to know about Kidney Failure and How Its Treated ?': 3,
#          'What is (are) Glomerular Diseases ?': 3,
#          'Who is at risk for Am I at Risk for Type 2 Diabetes? Taking Steps to Lower Your Risk of Getting Diabetes? ?': 3,
#          'What are the treatments for Nerve Disease and Bladder Control ?': 3,
#          'How to diagnose What I need to know about Gestational Diabetes ?': 3,
#          'What is (are) Anemia in Chronic Kidney Disease ?': 3,
#          'What is (are) Diabetic Kidney Disease ?': 3,
#          'What is (are) Diverticular Disease ?': 3,
#          'Who is at risk for Glaucoma? ?': 2,
#          'What causes High Blood Pressure ?': 2,
#          'Who is at risk for High Blood Pressure? ?': 2,
#          'What are the symptoms of High Blood Pressure ?': 2,
#          'How to diagnose High Blood Pressure ?': 2,
#          "What are the symptoms of Paget's Disease of Bone ?": 2,
#          "How to diagnose Paget's Disease of Bone ?": 2,
#          'What are the symptoms of Urinary Tract Infections ?': 2,
#          'How to prevent Urinary Tract Infections ?': 2,
#          'What causes Osteoarthritis ?': 2,
#          'What are the symptoms of Osteoarthritis ?': 2,
#          'What are the treatments for Problems with Taste ?': 2,
#          'what research (or clinical trials) is being done for Problems with Taste ?': 2,
#          'What are the treatments for Anxiety Disorders ?': 2,
#          'Who is at risk for Diabetes? ?': 2,
#          'What are the symptoms of Diabetes ?': 2,
#          'What are the symptoms of Balance Problems ?': 2,
#          'What causes Balance Problems ?': 2,
#          'What are the symptoms of Osteoporosis ?': 2,
#          'How to diagnose Osteoporosis ?': 2,
#          'What are the symptoms of Kidney Disease ?': 2,
#          'what research (or clinical trials) is being done for Kidney Disease ?': 2,
#          "What causes Alzheimer's Disease ?": 2,
#          'What causes Rheumatoid Arthritis ?': 2,
#          'What are the symptoms of Rheumatoid Arthritis ?': 2,
#          'How to diagnose Rheumatoid Arthritis ?': 2,
#          'What is (are) Hearing Loss ?': 2,
#          'What are the treatments for Hearing Loss ?': 2,
#          'What causes Low Vision ?': 2,
#          'How to prevent COPD ?': 2,
#          'How to diagnose COPD ?': 2,
#          'What are the treatments for COPD ?': 2,
#          'Who is at risk for Age-related Macular Degeneration? ?': 2,
#          'What causes Diabetic Retinopathy ?': 2,
#          'What are the symptoms of Depression ?': 2,
#          'What are the symptoms of Problems with Smell ?': 2,
#          'What are the treatments for Problems with Smell ?': 2,
#          'What are the symptoms of Colorectal Cancer ?': 2,
#          'what research (or clinical trials) is being done for Colorectal Cancer ?': 2,
#          'How to prevent Colorectal Cancer ?': 2,
#          "What causes Parkinson's Disease ?": 2,
#          'Who is at risk for Leukemia? ?': 2,
#          'What are the symptoms of Leukemia ?': 2,
#          'what research (or clinical trials) is being done for Leukemia ?': 2,
#          'What are the symptoms of Lung Cancer ?': 2,
#          'What causes Urinary Incontinence ?': 2,
#          'How to diagnose Urinary Incontinence ?': 2,
#          'How to diagnose Stroke ?': 2,
#          'What causes Psoriasis ?': 2,
#          'what research (or clinical trials) is being done for Psoriasis ?': 2,
#          'What causes High Blood Cholesterol ?': 2,
#          'What are the symptoms of High Blood Cholesterol ?': 2,
#          'How to diagnose High Blood Cholesterol ?': 2,
#          'How to prevent Peripheral Arterial Disease (P.A.D.) ?': 2,
#          'What are the symptoms of Peripheral Arterial Disease (P.A.D.) ?': 2,
#          'How to diagnose Peripheral Arterial Disease (P.A.D.) ?': 2,
#          'What are the symptoms of Prescription and Illicit Drug Abuse ?': 2,
#          'What are the symptoms of Cataract ?': 2,
#          'What are the treatments for Cataract ?': 2,
#          'How to diagnose Creating a Family Health History ?': 2,
#          'What causes Shingles ?': 2,
#          'How to prevent Shingles ?': 2,
#          'Who is at risk for Shingles? ?': 2,
#          'What are the symptoms of Skin Cancer ?': 2,
#          'How to diagnose Skin Cancer ?': 2,
#          'What causes Gout ?': 2,
#          'What are the symptoms of Gout ?': 2,
#          'What are the treatments for Gout ?': 2,
#          "How to diagnose Alzheimer's Caregiving ?": 2,
#          "What to do for Alzheimer's Caregiving ?": 2,
#          'What are the symptoms of Dry Eye ?': 2,
#          'What are the treatments for Dry Eye ?': 2,
#          'How to prevent Gum (Periodontal) Disease ?': 2,
#          'What are the symptoms of Gum (Periodontal) Disease ?': 2,
#          'How to prevent Heart Failure ?': 2,
#          'What is the outlook for Breast Cancer ?': 2,
#          'What are the stages of Breast Cancer ?': 2,
#          'What is (are) Vulvar Cancer ?': 2,
#          'What is (are) Gallbladder Cancer ?': 2,
#          'What is (are) Anal Cancer ?': 2,
#          'What is (are) Polycythemia Vera ?': 2,
#          'What are the symptoms of Polycythemia Vera ?': 2,
#          'How to diagnose Polycythemia Vera ?': 2,
#          'What are the treatments for Polycythemia Vera ?': 2,
#          'What is (are) Chronic Myelogenous Leukemia ?': 2,
#          'What are the treatments for Chronic Myelogenous Leukemia ?': 2,
#          'What is (are) Ovarian, Fallopian Tube, and Primary Peritoneal Cancer ?': 2,
#          'Who is at risk for Ovarian, Fallopian Tube, and Primary Peritoneal Cancer? ?': 2,
#          'What is (are) Liver (Hepatocellular) Cancer ?': 2,
#          'Who is at risk for Liver (Hepatocellular) Cancer? ?': 2,
#          'What is (are) Testicular Cancer ?': 2,
#          'What is (are) Myelodysplastic Syndromes ?': 2,
#          'what research (or clinical trials) is being done for Endometrial Cancer ?': 2,
#          'What is (are) Pancreatic Cancer ?': 2,
#          'What is (are) Salivary Gland Cancer ?': 2,
#          'Who is at risk for Neuroblastoma? ?': 2,
#          'What is (are) Chronic Lymphocytic Leukemia ?': 2,
#          'What is the outlook for Pituitary Tumors ?': 2,
#          'What are the treatments for Pituitary Tumors ?': 2,
#          'what research (or clinical trials) is being done for Pituitary Tumors ?': 2,
#          'What are the symptoms of Neuroblastoma ?': 2,
#          'What is (are) Male Breast Cancer ?': 2,
#          'What is (are) Melanoma ?': 2,
#          'What is (are) Oxygen Therapy ?': 2,
#          "What is (are) Huntington's Disease ?": 2,
#          'What is (are) Tremor ?': 2,
#          'What is (are) Endocarditis ?': 2,
#          'What is (are) Alpha-1 Antitrypsin Deficiency ?': 2,
#          'What is (are) Pneumonia ?': 2,
#          'What is (are) Coma ?': 2,
#          'What is (are) Dwarfism ?': 2,
#          'What is (are) Metabolic Syndrome ?': 2,
#          "What is (are) Bell's Palsy ?": 2,
#          'What is (are) Aplastic Anemia ?': 2,
#          'What is (are) Transient Ischemic Attack ?': 2,
#          'What is (are) Deep Vein Thrombosis ?': 2,
#          'What is (are) Respiratory Failure ?': 2,
#          'What is (are) Cirrhosis ?': 2,
#          'What is (are) Mitral Valve Prolapse ?': 2,
#          'What is (are) Diarrhea ?': 2,
#          'What is (are) Hemorrhoids ?': 2,
#          'What is (are) Swallowing Disorders ?': 2,
#          'What is (are) Chiari Malformation ?': 2,
#          'What is (are) Pulmonary Hypertension ?': 2,
#          'What is (are) Carpal Tunnel Syndrome ?': 2,
#          'What is (are) Dementia ?': 2,
#          'What is (are) Spina Bifida ?': 2,
#          'What is (are) Cerebral Palsy ?': 2,
#          'What is (are) Progressive Supranuclear Palsy ?': 2,
#          'What is (are) Aphasia ?': 2,
#          'What is (are) Indigestion ?': 2,
#          'What is (are) Scleroderma ?': 2,
#          'What is (are) Thalassemia ?': 2,
#          'What is (are) Aspergillosis ?': 2,
#          'What is (are) Diabetic Heart Disease ?': 2,
#          'What is (are) Rett Syndrome ?': 2,
#          'What is (are) Cardiomyopathy ?': 2,
#          'What is (are) Tuberous Sclerosis ?': 2,
#          'What is (are) Complex Regional Pain Syndrome ?': 2,
#          'What is (are) Migraine ?': 2,
#          'What is (are) Myasthenia Gravis ?': 2,
#          'What is (are) Trigeminal Neuralgia ?': 2,
#          'What is (are) Varicose Veins ?': 2,
#          'What is (are) Headache ?': 2,
#          "What is (are) Friedreich's Ataxia ?": 2,
#          'What is (are) Cough ?': 2,
#          'What is (are) Tourette Syndrome ?': 2,
#          'What is (are) Cystic Fibrosis ?': 2,
#          'What is (are) Charcot-Marie-Tooth Disease ?': 2,
#          'What is (are) Atrial Fibrillation ?': 2,
#          'What is (are) Traumatic Brain Injury ?': 2,
#          'What is (are) Marfan Syndrome ?': 2,
#          'What is (are) Carotid Artery Disease ?': 2,
#          'What is (are) Brachial Plexus Injuries ?': 2,
#          'What is (are) Creutzfeldt-Jakob Disease ?': 2,
#          'What is (are) Pulmonary Embolism ?': 2,
#          'What is (are) Rh Incompatibility ?': 2,
#          'What is (are) Chronic Pain ?': 2,
#          'What is (are) Lupus ?': 2,
#          'What is (are) Epilepsy ?': 2,
#          'What is (are) Arrhythmia ?': 2,
#          'What is (are) Multiple Sclerosis ?': 2,
#          'What is (are) Celiac Disease ?': 2,
#          'What is (are) Back Pain ?': 2,
#          'What is (are) Spinal Muscular Atrophy ?': 2,
#          'What is (are) Angina ?': 2,
#          'What is (are) Kawasaki Disease ?': 2,
#          'What is (are) Tay-Sachs Disease ?': 2,
#          'What is (are) Malaria ?': 2,
#          'What is (are) Congenital Heart Defects ?': 2,
#          'What is (are) Syringomyelia ?': 2,
#          'What is (are) Ataxia Telangiectasia ?': 2,
#          'What is (are) Rickets ?': 2,
#          'What is (are) Muscular Dystrophy ?': 2,
#          'What is (are) Atherosclerosis ?': 2,
#          'What is (are) Hydrocephalus ?': 2,
#          'What is (are) Vasculitis ?': 2,
#          'What is (are) Gaucher Disease ?': 2,
#          'What is (are) Insomnia ?': 2,
#          'What is (are) Thoracic Outlet Syndrome ?': 2,
#          'What is (are) Anemia ?': 2,
#          'What is (are) Brooke-Spiegler syndrome ?': 2,
#          'What is (are) Mowat-Wilson syndrome ?': 2,
#          'Is Mowat-Wilson syndrome inherited ?': 2,
#          'What are the symptoms of Asthma ?': 2,
#          'What is (are) Wolman disease ?': 2,
#          'What are the treatments for Wolman disease ?': 2,
#          'What is (are) L1 syndrome ?': 2,
#          'What is (are) VACTERL association ?': 2,
#          'What is (are) Alagille syndrome ?': 2,
#          'What is (are) Rabson-Mendenhall syndrome ?': 2,
#          'What is (are) 46,XX testicular disorder of sex development ?': 2,
#          'What is (are) Pendred syndrome ?': 2,
#          'Is Pendred syndrome inherited ?': 2,
#          'What is (are) Wilson disease ?': 2,
#          'Is Wilson disease inherited ?': 2,
#          'What are the treatments for Wilson disease ?': 2,
#          'What is (are) Russell-Silver syndrome ?': 2,
#          'Is Russell-Silver syndrome inherited ?': 2,
#          'What is (are) Beare-Stevenson cutis gyrata syndrome ?': 2,
#          'What is (are) Paget disease of bone ?': 2,
#          'What is (are) Fabry disease ?': 2,
#          'Is Fabry disease inherited ?': 2,
#          'What are the treatments for Fabry disease ?': 2,
#          'What is (are) Andermann syndrome ?': 2,
#          'What is (are) Miller-Dieker syndrome ?': 2,
#          'What is (are) Rett syndrome ?': 2,
#          'Is Rett syndrome inherited ?': 2,
#          'What is (are) Moebius syndrome ?': 2,
#          'Is Moebius syndrome inherited ?': 2,
#          'What is (are) 48,XXYY syndrome ?': 2,
#          'Is 48,XXYY syndrome inherited ?': 2,
#          'What is (are) Turner syndrome ?': 2,
#          'Is Turner syndrome inherited ?': 2,
#          'What is (are) Wolff-Parkinson-White syndrome ?': 2,
#          'Is Wolff-Parkinson-White syndrome inherited ?': 2,
#          'What is (are) Williams syndrome ?': 2,
#          'Is Williams syndrome inherited ?': 2,
#          'What is (are) CHOPS syndrome ?': 2,
#          'What is (are) Bartter syndrome ?': 2,
#          'Is Bartter syndrome inherited ?': 2,
#          'What are the treatments for Bartter syndrome ?': 2,
#          'What is (are) Partington syndrome ?': 2,
#          'Is Partington syndrome inherited ?': 2,
#          'What are the treatments for Partington syndrome ?': 2,
#          'What is (are) Acromegaly ?': 2,
#          'What are the symptoms of Acromegaly ?': 2,
#          'What is (are) Donnai-Barrow syndrome ?': 2,
#          'What is (are) Cohen syndrome ?': 2,
#          'What are the treatments for Cohen syndrome ?': 2,
#          'What is (are) 17-beta hydroxysteroid dehydrogenase 3 deficiency ?': 2,
#          'What is (are) Brody myopathy ?': 2,
#          'What are the treatments for Brody myopathy ?': 2,
#          'What is (are) Miller syndrome ?': 2,
#          'What is (are) Apert syndrome ?': 2,
#          'What is (are) Lennox-Gastaut syndrome ?': 2,
#          'What is (are) Norrie disease ?': 2,
#          'What are the treatments for Norrie disease ?': 2,
#          'What is (are) Floating-Harbor syndrome ?': 2,
#          'What are the treatments for Floating-Harbor syndrome ?': 2,
#          'What is (are) Dermatomyositis ?': 2,
#          'What are the treatments for Dermatomyositis ?': 2,
#          'What is (are) Emanuel syndrome ?': 2,
#          'What is (are) MECP2 duplication syndrome ?': 2,
#          'Is MECP2 duplication syndrome inherited ?': 2,
#          'What are the treatments for MECP2 duplication syndrome ?': 2,
#          'What is (are) X-linked adrenal hypoplasia congenita ?': 2,
#          'Is X-linked adrenal hypoplasia congenita inherited ?': 2,
#          'What is (are) Schizencephaly ?': 2,
#          'What are the treatments for Schizencephaly ?': 2,
#          'What is (are) Wolfram syndrome ?': 2,
#          'Is Wolfram syndrome inherited ?': 2,
#          'What are the treatments for Wolfram syndrome ?': 2,
#          'What is (are) Vohwinkel syndrome ?': 2,
#          'What is (are) Angelman syndrome ?': 2,
#          'Is Angelman syndrome inherited ?': 2,
#          'What is (are) Holt-Oram syndrome ?': 2,
#          'Is Holt-Oram syndrome inherited ?': 2,
#          'What are the treatments for Holt-Oram syndrome ?': 2,
#          'What is (are) Hermansky-Pudlak syndrome ?': 2,
#          'What is (are) Friedreich ataxia ?': 2,
#          'Is Friedreich ataxia inherited ?': 2,
#          'What is (are) Porencephaly ?': 2,
#          'What is (are) Tourette syndrome ?': 2,
#          'Is Tourette syndrome inherited ?': 2,
#          'What are the treatments for Tourette syndrome ?': 2,
#          'What is (are) Leukodystrophy ?': 2,
#          'What is (are) Snyder-Robinson syndrome ?': 2,
#          'What is (are) Danon disease ?': 2,
#          'Is Danon disease inherited ?': 2,
#          'What are the treatments for Danon disease ?': 2,
#          'What are the symptoms of Sarcoidosis ?': 2,
#          'What causes Sarcoidosis ?': 2,
#          'What are the treatments for Sarcoidosis ?': 2,
#          'What is (are) Marfan syndrome ?': 2,
#          'Is Marfan syndrome inherited ?': 2,
#          'What is (are) Huntington disease ?': 2,
#          'Is Huntington disease inherited ?': 2,
#          'What are the treatments for Huntington disease ?': 2,
#          'What is (are) Down syndrome ?': 2,
#          'What are the treatments for Down syndrome ?': 2,
#          'What is (are) Polymyositis ?': 2,
#          'What are the treatments for Polymyositis ?': 2,
#          'What is (are) Lenz microphthalmia syndrome ?': 2,
#          'What is (are) 22q13.3 deletion syndrome ?': 2,
#          'What is (are) Tietz syndrome ?': 2,
#          'What is (are) Klinefelter syndrome ?': 2,
#          'Is Klinefelter syndrome inherited ?': 2,
#          'What are the treatments for Klinefelter syndrome ?': 2,
#          'What is (are) Majeed syndrome ?': 2,
#          'Is Majeed syndrome inherited ?': 2,
#          'What are the treatments for Majeed syndrome ?': 2,
#          'What is (are) Ehlers-Danlos syndrome ?': 2,
#          'Is Ehlers-Danlos syndrome inherited ?': 2,
#          'What are the treatments for Ehlers-Danlos syndrome ?': 2,
#          'What is (are) Maffucci syndrome ?': 2,
#          'What are the treatments for Maffucci syndrome ?': 2,
#          'What is (are) Cowden syndrome ?': 2,
#          'Is Cowden syndrome inherited ?': 2,
#          'What are the treatments for Cowden syndrome ?': 2,
#          'What is (are) Neuroacanthocytosis ?': 2,
#          'What are the treatments for Neuroacanthocytosis ?': 2,
#          'What is (are) Baller-Gerold syndrome ?': 2,
#          'What is (are) Nicolaides-Baraitser syndrome ?': 2,
#          'Is Nicolaides-Baraitser syndrome inherited ?': 2,
#          'What is (are) Alport syndrome ?': 2,
#          'Is Alport syndrome inherited ?': 2,
#          'What are the treatments for Alport syndrome ?': 2,
#          'What is (are) Myhre syndrome ?': 2,
#          'Is Myhre syndrome inherited ?': 2,
#          'What are the treatments for Myhre syndrome ?': 2,
#          'What is (are) Rotor syndrome ?': 2,
#          'What are the treatments for Rotor syndrome ?': 2,
#          'What is (are) Leber hereditary optic neuropathy ?': 2,
#          'Is Leber hereditary optic neuropathy inherited ?': 2,
#          'What is (are) Greig cephalopolysyndactyly syndrome ?': 2,
#          'Is Greig cephalopolysyndactyly syndrome inherited ?': 2,
#          'What are the treatments for Greig cephalopolysyndactyly syndrome ?': 2,
#          'What is (are) Char syndrome ?': 2,
#          'What is (are) Unverricht-Lundborg disease ?': 2,
#          'What is (are) Coffin-Siris syndrome ?': 2,
#          'What are the treatments for Coffin-Siris syndrome ?': 2,
#          'What is (are) Lujan syndrome ?': 2,
#          'What is (are) Microcephaly ?': 2,
#          'What is (are) CADASIL ?': 2,
#          'What are the treatments for CADASIL ?': 2,
#          'What is (are) ADCY5-related dyskinesia ?': 2,
#          'What is (are) Peutz-Jeghers syndrome ?': 2,
#          'Is Peutz-Jeghers syndrome inherited ?': 2,
#          'What is (are) Laing distal myopathy ?': 2,
#          'What is (are) Gaucher disease ?': 2,
#          'What is (are) Fryns syndrome ?': 2,
#          'Is Fryns syndrome inherited ?': 2,
#          'What is (are) X-linked sideroblastic anemia ?': 2,
#          'What is (are) Parkes Weber syndrome ?': 2,
#          'What are the treatments for Parkes Weber syndrome ?': 2,
#          'What is (are) Carpenter syndrome ?': 2,
#          'What is (are) Meesmann corneal dystrophy ?': 2,
#          'What are the treatments for Meesmann corneal dystrophy ?': 2,
#          'What is (are) Milroy disease ?': 2,
#          'Is Milroy disease inherited ?': 2,
#          'What are the treatments for Milroy disease ?': 2,
#          'What is (are) Poland syndrome ?': 2,
#          'Is Poland syndrome inherited ?': 2,
#          'What are the treatments for Poland syndrome ?': 2,
#          'What is (are) WAGR syndrome ?': 2,
#          'What is (are) Glanzmann thrombasthenia ?': 2,
#          'What are the symptoms of Narcolepsy ?': 2,
#          'How to diagnose Narcolepsy ?': 2,
#          'What is (are) Pelizaeus-Merzbacher disease ?': 2,
#          'Is Pelizaeus-Merzbacher disease inherited ?': 2,
#          'What are the treatments for Pelizaeus-Merzbacher disease ?': 2,
#          'What is (are) FG syndrome ?': 2,
#          'What are the treatments for FG syndrome ?': 2,
#          'What is (are) Treacher Collins syndrome ?': 2,
#          'What are the treatments for Treacher Collins syndrome ?': 2,
#          'What is (are) Larsen syndrome ?': 2,
#          'Is Larsen syndrome inherited ?': 2,
#          'What is (are) Noonan syndrome ?': 2,
#          'Is Noonan syndrome inherited ?': 2,
#          'What are the treatments for Noonan syndrome ?': 2,
#          'What is (are) Loeys-Dietz syndrome ?': 2,
#          'What is (are) Cockayne syndrome ?': 2,
#          'What is (are) Fanconi anemia ?': 2,
#          'What is (are) Ollier disease ?': 2,
#          'What are the treatments for Ollier disease ?': 2,
#          'What is (are) 2-methylbutyryl-CoA dehydrogenase deficiency ?': 2,
#          'What is (are) 21-hydroxylase deficiency ?': 2,
#          'Is 21-hydroxylase deficiency inherited ?': 2,
#          'What are the treatments for 21-hydroxylase deficiency ?': 2,
#          'What is (are) Cushing disease ?': 2,
#          'What is (are) Kallmann syndrome ?': 2,
#          'Is Kallmann syndrome inherited ?': 2,
#          'What is (are) Opitz G/BBB syndrome ?': 2,
#          'Is Opitz G/BBB syndrome inherited ?': 2,
#          'What are the treatments for Opitz G/BBB syndrome ?': 2,
#          'What is (are) Pallister-Killian mosaic syndrome ?': 2,
#          'What is (are) Joubert syndrome ?': 2,
#          'Is Joubert syndrome inherited ?': 2,
#          'What is (are) Alzheimer disease ?': 2,
#          'What is (are) GRACILE syndrome ?': 2,
#          'What is (are) Asperger syndrome ?': 2,
#          'Is Asperger syndrome inherited ?': 2,
#          'What is (are) Anencephaly ?': 2,
#          'What is (are) Potocki-Shaffer syndrome ?': 2,
#          'What are the treatments for Potocki-Shaffer syndrome ?': 2,
#          'What is (are) Cornelia de Lange syndrome ?': 2,
#          'Is Cornelia de Lange syndrome inherited ?': 2,
#          'What are the treatments for Cornelia de Lange syndrome ?': 2,
#          'What is (are) Tetralogy of Fallot ?': 2,
#          'What are the symptoms of Tetralogy of Fallot ?': 2,
#          'What is (are) X-linked creatine deficiency ?': 2,
#          'What is (are) X-linked congenital stationary night blindness ?': 2,
#          'What is (are) GM1 gangliosidosis ?': 2,
#          'Is GM1 gangliosidosis inherited ?': 2,
#          'What are the treatments for GM1 gangliosidosis ?': 2,
#          'What is (are) Arts syndrome ?': 2,
#          'Is Arts syndrome inherited ?': 2,
#          'What is (are) 22q11.2 deletion syndrome ?': 2,
#          'Is 22q11.2 deletion syndrome inherited ?': 2,
#          'What is (are) Robinow syndrome ?': 2,
#          'Is Robinow syndrome inherited ?': 2,
#          'What is (are) Carney complex ?': 2,
#          'What is (are) Erdheim-Chester disease ?': 2,
#          'What is (are) Sotos syndrome ?': 2,
#          'Is Sotos syndrome inherited ?': 2,
#          'What is (are) Costello syndrome ?': 2,
#          'What is (are) Lynch syndrome ?': 2,
#          'Is Lynch syndrome inherited ?': 2,
#          'What is (are) Colpocephaly ?': 2,
#          'What are the treatments for Colpocephaly ?': 2,
#          'What is (are) Troyer syndrome ?': 2,
#          'Is Troyer syndrome inherited ?': 2,
#          'What are the treatments for Troyer syndrome ?': 2,
#          'What is (are) Hennekam syndrome ?': 2,
#          'What is (are) Ewing sarcoma ?': 2,
#          'Is Ewing sarcoma inherited ?': 2,
#          'What is (are) Laron syndrome ?': 2,
#          'Is Laron syndrome inherited ?': 2,
#          'What are the treatments for Laron syndrome ?': 2,
#          'What is (are) 2q37 deletion syndrome ?': 2,
#          'Is 2q37 deletion syndrome inherited ?': 2,
#          'What is (are) Chanarin-Dorfman syndrome ?': 2,
#          'What is (are) Langerhans cell histiocytosis ?': 2,
#          'Is Langerhans cell histiocytosis inherited ?': 2,
#          'What are the treatments for Langerhans cell histiocytosis ?': 2,
#          'What is (are) Proteus syndrome ?': 2,
#          'What is (are) X-linked agammaglobulinemia ?': 2,
#          'What are the treatments for X-linked agammaglobulinemia ?': 2,
#          'What is (are) Dowling-Degos disease ?': 2,
#          'What are the treatments for Dowling-Degos disease ?': 2,
#          'What is (are) Weaver syndrome ?': 2,
#          'What is (are) Roberts syndrome ?': 2,
#          'What is (are) Hydranencephaly ?': 2,
#          'What are the treatments for Hydranencephaly ?': 2,
#          'What is (are) Tay-Sachs disease ?': 2,
#          'Is Tay-Sachs disease inherited ?': 2,
#          'What are the treatments for Tay-Sachs disease ?': 2,
#          'What is (are) Muckle-Wells syndrome ?': 2,
#          'What is (are) Parkinson disease ?': 2,
#          'Is Parkinson disease inherited ?': 2,
#          'What is (are) Andersen-Tawil syndrome ?': 2,
#          'What is (are) Charcot-Marie-Tooth disease ?': 2,
#          'What is (are) Peters plus syndrome ?': 2,
#          'Is Peters plus syndrome inherited ?': 2,
#          'What are the treatments for Peters plus syndrome ?': 2,
#          'What is (are) Camurati-Engelmann disease ?': 2,
#          'Is Camurati-Engelmann disease inherited ?': 2,
#          'What are the treatments for Camurati-Engelmann disease ?': 2,
#          'What is (are) Northern epilepsy ?': 2,
#          'What is (are) Prader-Willi syndrome ?': 2,
#          'Is Prader-Willi syndrome inherited ?': 2,
#          'What are the treatments for Prader-Willi syndrome ?': 2,
#          'What is (are) Denys-Drash syndrome ?': 2,
#          'Is Denys-Drash syndrome inherited ?': 2,
#          'What is (are) KBG syndrome ?': 2,
#          'What is (are) Gilbert syndrome ?': 2,
#          'Is Gilbert syndrome inherited ?': 2,
#          'What are the treatments for Gilbert syndrome ?': 2,
#          'What is (are) Weill-Marchesani syndrome ?': 2,
#          'What are the treatments for Weill-Marchesani syndrome ?': 2,
#          'What is (are) Waardenburg syndrome ?': 2,
#          'What is (are) Liddle syndrome ?': 2,
#          'Is Liddle syndrome inherited ?': 2,
#          'What are the treatments for Liddle syndrome ?': 2,
#          'What is (are)  ?': 2,
#          'Who is at risk for Omsk Hemorrhagic Fever (OHF)? ?': 2,
#          'Who is at risk for Chapare Hemorrhagic Fever (CHHF)? ?': 2,
#          'Who is at risk for Alkhurma Hemorrhagic Fever (AHF)? ?': 2,
#          'Who is at risk for Crimean-Congo Hemorrhagic Fever (CCHF)? ?': 2,
#          'Who is at risk for Kyasanur Forest Disease (KFD)? ?': 2,
#          'Who is at risk for Marburg hemorrhagic fever (Marburg HF)? ?': 2,
#          'Who is at risk for Nocardiosis? ?': 2,
#          'Who is at risk for Lymphocytic Choriomeningitis (LCM)? ?': 2,
#          'Who is at risk for Lujo Hemorrhagic Fever (LUHF)? ?': 2,
#          'Who is at risk for Hendra Virus Disease (HeV)? ?': 2,
#          'What is the outlook for Oxygen Therapy ?': 2,
#          'What are the treatments for Sleep Apnea ?': 2,
#          'What is (are) Restless Legs Syndrome ?': 2,
#          'What are the treatments for Restless Legs Syndrome ?': 2,
#          'Who is at risk for Overweight and Obesity? ?': 2,
#          'How to diagnose Hemochromatosis ?': 2,
#          'What are the treatments for Hemochromatosis ?': 2,
#          "What are the treatments for Cushing's Syndrome ?": 2,
#          'What are the treatments for Machado-Joseph Disease ?': 2,
#          'What is the outlook for Machado-Joseph Disease ?': 2,
#          'what research (or clinical trials) is being done for Machado-Joseph Disease ?': 2,
#          'What are the treatments for Wilson Disease ?': 2,
#          'What is (are) Mineral and Bone Disorder in Chronic Kidney Disease ?': 2,
#          'What causes Urinary Incontinence in Children ?': 2,
#          'What to do for Urinary Incontinence in Children ?': 2,
#          'What to do for Hemochromatosis ?': 2,
#          'What to do for Ulcerative Colitis ?': 2,
#          'What are the treatments for What I need to know about Cirrhosis ?': 2,
#          'What is (are) Urinary Retention ?': 2,
#          'What are the treatments for Urinary Retention ?': 2,
#          'What to do for Urinary Retention ?': 2,
#          'What is (are) Growth Failure in Children with Chronic Kidney Disease ?': 2,
#          'What to do for Growth Failure in Children with Chronic Kidney Disease ?': 2,
#          'What to do for Nephrotic Syndrome in Adults ?': 2,
#          'What is (are) Pyelonephritis: Kidney Infection ?': 2,
#          'What to do for Pyelonephritis: Kidney Infection ?': 2,
#          'What to do for Gas in the Digestive Tract ?': 2,
#          "What causes Adrenal Insufficiency and Addison's Disease ?": 2,
#          "How to diagnose Adrenal Insufficiency and Addison's Disease ?": 2,
#          "What to do for Adrenal Insufficiency and Addison's Disease ?": 2,
#          'How to prevent Prevent diabetes problems: Keep your heart and blood vessels healthy ?': 2,
#          'What are the symptoms of Prevent diabetes problems: Keep your heart and blood vessels healthy ?': 2,
#          'What are the symptoms of Celiac Disease ?': 2,
#          'How to diagnose Celiac Disease ?': 2,
#          'What to do for Celiac Disease ?': 2,
#          "What is (are) Hashimoto's Disease ?": 2,
#          "What to do for Hashimoto's Disease ?": 2,
#          'What to do for Kidney Stones in Children ?': 2,
#          'What to do for Autoimmune Hepatitis ?': 2,
#          'What is (are) Whipple Disease ?': 2,
#          'What to do for Whipple Disease ?': 2,
#          'What is (are) Prolactinoma ?': 2,
#          'What causes Prolactinoma ?': 2,
#          'What to do for Intestinal Pseudo-obstruction ?': 2,
#          'What to do for What I need to know about Erectile Dysfunction ?': 2,
#          'What is (are) What I need to know about Diverticular Disease ?': 2,
#          'What is (are) Prevent diabetes problems: Keep your nervous system healthy ?': 2,
#          'What is (are) Proctitis ?': 2,
#          'What causes Proctitis ?': 2,
#          'What are the treatments for Proctitis ?': 2,
#          'What to do for Proctitis ?': 2,
#          'What are the symptoms of Short Bowel Syndrome ?': 2,
#          'What to do for Short Bowel Syndrome ?': 2,
#          'What is (are) Acquired Cystic Kidney Disease ?': 2,
#          'What to do for Acquired Cystic Kidney Disease ?': 2,
#          'What is (are) Human Growth Hormone and Creutzfeldt-Jakob Disease Resource List ?': 2,
#          'What is (are) Simple Kidney Cysts ?': 2,
#          'What to do for Simple Kidney Cysts ?': 2,
#          'How to diagnose Kidney Disease of Diabetes ?': 2,
#          'How to prevent Kidney Disease of Diabetes ?': 2,
#          'What to do for Kidney Disease of Diabetes ?': 2,
#          'What is (are) Hepatitis B: What Asian and Pacific Islander Americans Need to Know ?': 2,
#          'Who is at risk for Hepatitis B: What Asian and Pacific Islander Americans Need to Know? ?': 2,
#          'What is (are) Solitary Kidney ?': 2,
#          'What to do for Solitary Kidney ?': 2,
#          'What to do for What I need to know about Hepatitis B ?': 2,
#          "What to do for Kidney Failure: Choosing a Treatment That's Right for You ?": 2,
#          'What to do for Diarrhea ?': 2,
#          'What to do for Wilson Disease ?': 2,
#          "What to do for Crohn's Disease ?": 2,
#          'What to do for What I need to know about Kidney Stones ?': 2,
#          'What is (are) What I need to know about Hirschsprung Disease ?': 2,
#          'What causes What I need to know about Hirschsprung Disease ?': 2,
#          'What to do for Gallstones ?': 2,
#          'What is (are) Smoking and the Digestive System ?': 2,
#          'What to do for Smoking and the Digestive System ?': 2,
#          "What is (are) Graves' Disease ?": 2,
#          "What are the treatments for Graves' Disease ?": 2,
#          "What to do for Graves' Disease ?": 2,
#          'What to do for What I need to know about Gas ?': 2,
#          'What to do for Diabetes, Heart Disease, and Stroke ?': 2,
#          "How to diagnose What I need to know about My Child's Urinary Tract Infection ?": 2,
#          "What to do for What I need to know about My Child's Urinary Tract Infection ?": 2,
#          'What are the symptoms of Hypoglycemia ?': 2,
#          'What causes Hypoglycemia ?': 2,
#          'What are the treatments for Hypoglycemia ?': 2,
#          'What to do for Hypoglycemia ?': 2,
#          'What to do for Overview of Kidney Disease in Children ?': 2,
#          'What is (are) What I need to know about Lactose Intolerance ?': 2,
#          'What to do for What I need to know about Lactose Intolerance ?': 2,
#          "What to do for Peyronie's Disease ?": 2,
#          'What is (are) Gastroparesis ?': 2,
#          'What are the treatments for Gastroparesis ?': 2,
#          'What to do for Gastroparesis ?': 2,
#          'What is (are) Alagille Syndrome ?': 2,
#          'What to do for Alagille Syndrome ?': 2,
#          'How to diagnose IgA Nephropathy ?': 2,
#          'What to do for IgA Nephropathy ?': 2,
#          'What is (are) Anemia of Inflammation and Chronic Disease ?': 2,
#          'What to do for Anemia of Inflammation and Chronic Disease ?': 2,
#          'What is (are) Treatment Methods for Kidney Failure: Peritoneal Dialysis ?': 2,
#          'What to do for Treatment Methods for Kidney Failure: Peritoneal Dialysis ?': 2,
#          'How to diagnose Primary Hyperparathyroidism ?': 2,
#          'What to do for Primary Hyperparathyroidism ?': 2,
#          'What is (are) Irritable Bowel Syndrome in Children ?': 2,
#          'What to do for Irritable Bowel Syndrome in Children ?': 2,
#          'What to do for Cirrhosis ?': 2,
#          'What to do for Lactose Intolerance ?': 2,
#          'What to do for Biliary Atresia ?': 2,
#          'What to do for Hyperthyroidism ?': 2,
#          'What are the symptoms of Gastritis ?': 2,
#          'What to do for Gastritis ?': 2,
#          'What to do for Fecal Incontinence ?': 2,
#          'What is (are) Abdominal Adhesions ?': 2,
#          'What are the symptoms of Abdominal Adhesions ?': 2,
#          'What to do for Abdominal Adhesions ?': 2,
#          'What to do for Porphyria ?': 2,
#          'What are the symptoms of Polycystic Kidney Disease ?': 2,
#          'What are the complications of Polycystic Kidney Disease ?': 2,
#          'What to do for Polycystic Kidney Disease ?': 2,
#          'What to do for What I need to know about Kidney Failure and How Its Treated ?': 2,
#          'What causes Perineal Injury in Males ?': 2,
#          'What to do for Perineal Injury in Males ?': 2,
#          'What is (are) Ectopic Kidney ?': 2,
#          'What to do for Ectopic Kidney ?': 2,
#          'What is (are) Hematuria (Blood in the Urine) ?': 2,
#          'What to do for Hematuria (Blood in the Urine) ?': 2,
#          'What to do for Urine Blockage in Newborns ?': 2,
#          'What is (are) What I need to know about Bladder Control for Women ?': 2,
#          'How to diagnose Glomerular Diseases ?': 2,
#          'What causes Glomerular Diseases ?': 2,
#          'What to do for Glomerular Diseases ?': 2,
#          'What is (are) Am I at Risk for Type 2 Diabetes? Taking Steps to Lower Your Risk of Getting Diabetes ?': 2,
#          'What to do for Insulin Resistance and Prediabetes ?': 2,
#          'Who is at risk for I Can Lower My Risk for Type 2 Diabetes: A Guide for American Indians? ?': 2,
#          'What is (are) Renal Artery Stenosis ?': 2,
#          'What to do for Renal Artery Stenosis ?': 2,
#          'What are the symptoms of Amyloidosis and Kidney Disease ?': 2,
#          'How to diagnose Amyloidosis and Kidney Disease ?': 2,
#          'What are the treatments for Amyloidosis and Kidney Disease ?': 2,
#          'What to do for Amyloidosis and Kidney Disease ?': 2,
#          'What to do for Primary Biliary Cirrhosis ?': 2,
#          'How to diagnose Proteinuria ?': 2,
#          'What is (are) Prostate Enlargement: Benign Prostatic Hyperplasia ?': 2,
#          'What are the treatments for Prostate Enlargement: Benign Prostatic Hyperplasia ?': 2,
#          'What to do for Prostate Enlargement: Benign Prostatic Hyperplasia ?': 2,
#          'What is (are) Dumping Syndrome ?': 2,
#          'What to do for Dumping Syndrome ?': 2,
#          'How to diagnose Renal Tubular Acidosis ?': 2,
#          'What to do for Renal Tubular Acidosis ?': 2,
#          'What is (are) Kidney Dysplasia ?': 2,
#          'What is the outlook for Kidney Dysplasia ?': 2,
#          'What to do for Kidney Dysplasia ?': 2,
#          'What to do for Viral Gastroenteritis ?': 2,
#          'What is (are) Diagnosis of Diabetes and Prediabetes ?': 2,
#          'How to diagnose Diagnosis of Diabetes and Prediabetes ?': 2,
#          'What causes Nerve Disease and Bladder Control ?': 2,
#          'What to do for Kidney Failure: What to Expect ?': 2,
#          'What is (are) What I need to know about Hepatitis A ?': 2,
#          'What to do for What I need to know about Hepatitis A ?': 2,
#          'What is (are) Prevent diabetes problems: Keep your diabetes under control ?': 2,
#          'What to do for What I need to know about Hepatitis C ?': 2,
#          'What is (are) High Blood Pressure and Kidney Disease ?': 2,
#          'What to do for High Blood Pressure and Kidney Disease ?': 2,
#          'What to do for Goodpasture Syndrome ?': 2,
#          'What is (are) Urinary Tract Infections in Children ?': 2,
#          'How to diagnose Urinary Tract Infections in Children ?': 2,
#          'What are the treatments for Urinary Tract Infections in Children ?': 2,
#          'What to do for Urinary Tract Infections in Children ?': 2,
#          'What to do for Facing the Challenges of Chronic Kidney Disease in Children ?': 2,
#          'What to do for Foodborne Illnesses ?': 2,
#          'What to do for Hypothyroidism ?': 2,
#          'How to prevent Medullary Sponge Kidney ?': 2,
#          'What to do for Medullary Sponge Kidney ?': 2,
#          'What is (are) Lupus Nephritis ?': 2,
#          'What to do for Lupus Nephritis ?': 2,
#          'What is (are) What I need to know about Gestational Diabetes ?': 2,
#          'What to do for What I need to know about Gestational Diabetes ?': 2,
#          'What is (are) Your Guide to Diabetes: Type 1 and Type 2 ?': 2,
#          'What is (are) Urinary Tract Infection In Adults ?': 2,
#          'What is (are) Pregnancy and Thyroid Disease ?': 2,
#          'What to do for Pregnancy and Thyroid Disease ?': 2,
#          "What is (are) What I need to know about Crohn's Disease ?": 2,
#          "What to do for What I need to know about Crohn's Disease ?": 2,
#          'What causes Chronic Diarrhea in Children ?': 2,
#          'What to do for Chronic Diarrhea in Children ?': 2,
#          'What to do for Anemia in Chronic Kidney Disease ?': 2,
#          'What is (are) Vesicoureteral Reflux ?': 2,
#          'How to diagnose Vesicoureteral Reflux ?': 2,
#          'What are the treatments for Vesicoureteral Reflux ?': 2,
#          'What to do for Vesicoureteral Reflux ?': 2,
#          'How to diagnose Diabetic Kidney Disease ?': 2,
#          'What are the treatments for Diabetic Kidney Disease ?': 2,
#          'What is (are) Hemolytic Uremic Syndrome in Children ?': 2,
#          'What to do for Hemolytic Uremic Syndrome in Children ?': 2,
#          'What is (are) Zollinger-Ellison Syndrome ?': 2,
#          'What are the symptoms of Zollinger-Ellison Syndrome ?': 2,
#          'What to do for Zollinger-Ellison Syndrome ?': 2,
#          'What to do for Cystocele ?': 2,
#          'What is (are) Inguinal Hernia ?': 2,
#          'What to do for Inguinal Hernia ?': 2,
#          'What are the treatments for What I need to know about Living with Kidney Failure ?': 2,
#          'What to do for What I need to know about Living with Kidney Failure ?': 2,
#          'What to do for What I need to know about Diarrhea ?': 2,
#          'What to do for Henoch-Schnlein Purpura ?': 2,
#          'What is (are) Childhood Nephrotic Syndrome ?': 2,
#          'What to do for Childhood Nephrotic Syndrome ?': 2,
#          'What to do for Mntriers Disease ?': 2,
#          'What are the treatments for Diverticular Disease ?': 2,
#          'What to do for Diverticular Disease ?': 2,
#          'What is (are) Microscopic Colitis: Collagenous Colitis and Lymphocytic Colitis ?': 2,
#          'What to do for Microscopic Colitis: Collagenous Colitis and Lymphocytic Colitis ?': 2,
#          'What is (are) Cyclic Vomiting Syndrome ?': 2,
#          'What are the symptoms of Cyclic Vomiting Syndrome ?': 2,
#          'What to do for Cyclic Vomiting Syndrome ?': 2,
#          'How to prevent Glaucoma ?': 1,
#          'What are the symptoms of Glaucoma ?': 1,
#          'What are the treatments for Glaucoma ?': 1,
#          'what research (or clinical trials) is being done for Glaucoma ?': 1,
#          "What are the complications of Paget's Disease of Bone ?": 1,
#          'What causes Urinary Tract Infections ?': 1,
#          'Who is at risk for Urinary Tract Infections? ?': 1,
#          'What are the treatments for Urinary Tract Infections ?': 1,
#          'What are the symptoms of Alcohol Use and Older Adults ?': 1,
#          'Where to find support for people with Alcohol Use and Older Adults ?': 1,
#          'How many people are affected by Osteoarthritis ?': 1,
#          'How to diagnose Osteoarthritis ?': 1,
#          'What are the symptoms of Problems with Taste ?': 1,
#          'How many people are affected by Problems with Taste ?': 1,
#          'How to prevent Problems with Taste ?': 1,
#          'How to diagnose Problems with Taste ?': 1,
#          'What are the symptoms of Anxiety Disorders ?': 1,
#          'How to diagnose Anxiety Disorders ?': 1,
#          'what research (or clinical trials) is being done for Anxiety Disorders ?': 1,
#          'How many people are affected by Anxiety Disorders ?': 1,
#          'Who is at risk for Anxiety Disorders? ?': 1,
#          'What causes Diabetes ?': 1,
#          'What to do for Medicare and Continuing Care ?': 1,
#          'What is the outlook for Knee Replacement ?': 1,
#          'What are the treatments for Knee Replacement ?': 1,
#          'Who is at risk for Knee Replacement? ?': 1,
#          'How many people are affected by Balance Problems ?': 1,
#          'What causes Quitting Smoking for Older Adults ?': 1,
#          'How many people are affected by Prostate Cancer ?': 1,
#          'What causes Prostate Cancer ?': 1,
#          'What are the symptoms of Dry Mouth ?': 1,
#          'what research (or clinical trials) is being done for Osteoporosis ?': 1,
#          'How to prevent Osteoporosis ?': 1,
#          'How to prevent Kidney Disease ?': 1,
#          'What causes Kidney Disease ?': 1,
#          'Who is at risk for Kidney Disease? ?': 1,
#          "What are the symptoms of Alzheimer's Disease ?": 1,
#          'what research (or clinical trials) is being done for Rheumatoid Arthritis ?': 1,
#          'What are the symptoms of Hearing Loss ?': 1,
#          'How many people are affected by Hearing Loss ?': 1,
#          'What causes Hearing Loss ?': 1,
#          'What are the symptoms of Low Vision ?': 1,
#          'Who is at risk for Low Vision? ?': 1,
#          'What causes Age-related Macular Degeneration ?': 1,
#          'How to prevent Age-related Macular Degeneration ?': 1,
#          'what research (or clinical trials) is being done for Age-related Macular Degeneration ?': 1,
#          'Who is at risk for Diabetic Retinopathy? ?': 1,
#          'what research (or clinical trials) is being done for Diabetic Retinopathy ?': 1,
#          'What to do for Diabetic Retinopathy ?': 1,
#          'What causes Depression ?': 1,
#          'what research (or clinical trials) is being done for Depression ?': 1,
#          'Who is at risk for Depression? ?': 1,
#          'How to prevent Problems with Smell ?': 1,
#          'How to diagnose Problems with Smell ?': 1,
#          'what research (or clinical trials) is being done for Problems with Smell ?': 1,
#          'How many people are affected by Colorectal Cancer ?': 1,
#          "Who is at risk for Parkinson's Disease? ?": 1,
#          "How to diagnose Parkinson's Disease ?": 1,
#          'How to diagnose Leukemia ?': 1,
#          'what research (or clinical trials) is being done for Lung Cancer ?': 1,
#          'How to diagnose Lung Cancer ?': 1,
#          'What are the symptoms of Psoriasis ?': 1,
#          'How to diagnose Psoriasis ?': 1,
#          'What causes Peripheral Arterial Disease (P.A.D.) ?': 1,
#          'Who is at risk for Peripheral Arterial Disease (P.A.D.)? ?': 1,
#          'What are the treatments for Peripheral Arterial Disease (P.A.D.) ?': 1,
#          'what research (or clinical trials) is being done for Peripheral Arterial Disease (P.A.D.) ?': 1,
#          'How to prevent Prescription and Illicit Drug Abuse ?': 1,
#          'What causes Prescription and Illicit Drug Abuse ?': 1,
#          'Who is at risk for Creating a Family Health History? ?': 1,
#          'What causes Creating a Family Health History ?': 1,
#          'How to prevent Creating a Family Health History ?': 1,
#          'How to diagnose Shingles ?': 1,
#          'What are the complications of Shingles ?': 1,
#          'How many people are affected by Heart Attack ?': 1,
#          'What causes Skin Cancer ?': 1,
#          'How to diagnose Surviving Cancer ?': 1,
#          'What are the symptoms of Surviving Cancer ?': 1,
#          'what research (or clinical trials) is being done for Gout ?': 1,
#          'How to diagnose Gout ?': 1,
#          "What are the treatments for Alzheimer's Caregiving ?": 1,
#          'How to diagnose Dry Eye ?': 1,
#          'Who is at risk for Gum (Periodontal) Disease? ?': 1,
#          'How to diagnose Gum (Periodontal) Disease ?': 1,
#          'How many people are affected by Heart Failure ?': 1,
#          'What is (are) Hairy Cell Leukemia ?': 1,
#          'Who is at risk for Hairy Cell Leukemia? ?': 1,
#          'What are the symptoms of Hairy Cell Leukemia ?': 1,
#          'How to diagnose Hairy Cell Leukemia ?': 1,
#          'What is the outlook for Hairy Cell Leukemia ?': 1,
#          'What are the stages of Hairy Cell Leukemia ?': 1,
#          'what research (or clinical trials) is being done for Hairy Cell Leukemia ?': 1,
#          'What are the treatments for Hairy Cell Leukemia ?': 1,
#          'What are the symptoms of Vulvar Cancer ?': 1,
#          'How to diagnose Vulvar Cancer ?': 1,
#          'What is the outlook for Vulvar Cancer ?': 1,
#          'What are the stages of Vulvar Cancer ?': 1,
#          'what research (or clinical trials) is being done for Vulvar Cancer ?': 1,
#          'What are the treatments for Vulvar Cancer ?': 1,
#          'Who is at risk for Gallbladder Cancer? ?': 1,
#          'What are the symptoms of Gallbladder Cancer ?': 1,
#          'How to diagnose Gallbladder Cancer ?': 1,
#          'What is the outlook for Gallbladder Cancer ?': 1,
#          'What are the stages of Gallbladder Cancer ?': 1,
#          'What are the treatments for Gallbladder Cancer ?': 1,
#          'what research (or clinical trials) is being done for Gallbladder Cancer ?': 1,
#          'What is (are) Atypical Chronic Myelogenous Leukemia ?': 1,
#          'What are the symptoms of Atypical Chronic Myelogenous Leukemia ?': 1,
#          'What is the outlook for Atypical Chronic Myelogenous Leukemia ?': 1,
#          'What are the treatments for Atypical Chronic Myelogenous Leukemia ?': 1,
#          'What is (are) Myelodysplastic/ Myeloproliferative Neoplasms ?': 1,
#          ...})

# %% [markdown]
# # Normalize questions

# %%
def clean_question(q):
    """
    This function removes unncessary spaces, and extra '?' from the questions and lowercases everything.
    Args:
        q (str): a string of question
    Returns:
        str : clean question.
    """
    q = q.strip().lower()
    q = re.sub(r'\s+', ' ', q)                   # collapse multiple spaces
    q = re.sub(r'\s+([?.!,])', r'\1', q)         # remove space before punctuation
    q = re.sub(r'([?.!,]){2,}', r'\1', q)        # collapse repeated punctuation
    return q

def clean_answer(text):
    """
    This function removes emails, urls, bullet points and extra white spaces from the answers.
    Args:
        text (str) : the answer associated with questions.

    Returns:
        str : clean text.
    """
    text = re.sub(r'\S+@\S+', '', text)  # Remove emails
    text = re.sub(r'http\S+|www\.\S+', '', text)  # remove URLs
    text = re.sub(r'-\s+', '', text)  # remove bullets
    text = re.sub(r'\s+', ' ', text)  # normalize whitespace
    text = text.strip()
    return text

# %%
# Count of answers per question post cleaning.

clean_q_to_a = defaultdict(list)
clean_q_to_a_cnt = {}

for question, answers in question_to_answers.items():
    clean_q = clean_question(question) 
    clean_a = [clean_answer(answer) for answer in answers]
    clean_q_to_a[clean_q].extend(clean_a)

for q, a in clean_q_to_a.items():
    clean_q_to_a_cnt[q] = len(a)

clean_q_to_a_cnt = dict(sorted(clean_q_to_a_cnt.items(), key=lambda x:x[1], reverse=True))

# %%
print('Total unique questions post cleaning and normalization: ',len(clean_q_to_a))
# Out:
# Total unique questions post cleaning and normalization:  14342

# %%
clean_q_to_a_cnt
# Out:
# {'what causes causes of diabetes?': 20,
#  'what is (are) high blood cholesterol?': 19,
#  'what is (are) medicare and continuing care?': 14,
#  'what is (are) breast cancer?': 13,
#  'what are the treatments for breast cancer?': 13,
#  'what is (are) stroke?': 13,
#  'what is (are) skin cancer?': 13,
#  'what is (are) colorectal cancer?': 12,
#  'what is (are) kidney failure: eat right to feel right on hemodialysis?': 12,
#  'what is (are) high blood pressure?': 11,
#  'what are the treatments for prostate cancer?': 11,
#  "what is (are) parkinson's disease?": 11,
#  'what is (are) prostate cancer?': 10,
#  'what is (are) age-related macular degeneration?': 10,
#  'what is (are) leukemia?': 10,
#  'what is (are) nutrition for advanced chronic kidney disease in adults?': 10,
#  'who is at risk for prostate cancer?': 9,
#  'who is at risk for breast cancer?': 9,
#  'what is (are) lung cancer?': 9,
#  'what is (are) diabetes?': 8,
#  'what is (are) dry mouth?': 8,
#  "what is (are) alzheimer's disease?": 8,
#  'what are the treatments for lung cancer?': 8,
#  'what is (are) psoriasis?': 7,
#  'what are the treatments for prescription and illicit drug abuse?': 7,
#  'what is (are) cataract?': 7,
#  'what is (are) creating a family health history?': 7,
#  'what is (are) heart attack?': 7,
#  'what is (are) anxiety disorders?': 6,
#  'what is (are) knee replacement?': 6,
#  'what is (are) osteoporosis?': 6,
#  'who is at risk for osteoporosis?': 6,
#  "what research (or clinical trials) is being done for alzheimer's disease?": 6,
#  'what is (are) diabetic retinopathy?': 6,
#  'who is at risk for colorectal cancer?': 6,
#  'who is at risk for lung cancer?': 6,
#  'what are the treatments for psoriasis?': 6,
#  'what are the treatments for surviving cancer?': 6,
#  "what is (are) alzheimer's caregiving?": 6,
#  'what are the treatments for gum (periodontal) disease?': 6,
#  'what is (are) heart failure?': 6,
#  'what are the treatments for heart failure?': 6,
#  'what is (are) wilson disease?': 6,
#  'what is (are) financial help for diabetes care?': 6,
#  'what is (are) diabetes, heart disease, and stroke?': 6,
#  'what is (are) what i need to know about kidney failure and how its treated?': 6,
#  'what are the treatments for national hormone and pituitary program (nhpp): information for people treated with pituitary human growth hormone (comprehensive report)?': 6,
#  'what is (are) diabetic neuropathies: the nerve damage of diabetes?': 6,
#  'what is (are) glaucoma?': 5,
#  'what are the treatments for alcohol use and older adults?': 5,
#  'what are the treatments for osteoarthritis?': 5,
#  'what is (are) balance problems?': 5,
#  'what is (are) kidney disease?': 5,
#  'what are the treatments for kidney disease?': 5,
#  "how to prevent alzheimer's disease?": 5,
#  'what is (are) rheumatoid arthritis?': 5,
#  'what are the treatments for diabetic retinopathy?': 5,
#  'what research (or clinical trials) is being done for breast cancer?': 5,
#  'what are the treatments for leukemia?': 5,
#  'what are the treatments for stroke?': 5,
#  'who is at risk for cataract?': 5,
#  'what is (are) shingles?': 5,
#  'what are the treatments for heart attack?': 5,
#  'who is at risk for skin cancer?': 5,
#  'what is (are) surviving cancer?': 5,
#  'what is (are) dry eye?': 5,
#  'what is (are) neuroblastoma?': 5,
#  'what is (are) lactose intolerance?': 5,
#  'what is (are) porphyria?': 5,
#  'what is (are) autoimmune hepatitis?': 5,
#  'what is (are) polycystic kidney disease?': 5,
#  "what is (are) kidney failure: choosing a treatment that's right for you?": 5,
#  'how to prevent high blood pressure?': 4,
#  'what are the treatments for high blood pressure?': 4,
#  'what is (are) alcohol use and older adults?': 4,
#  'what are the treatments for diabetes?': 4,
#  'what is (are) quitting smoking for older adults?': 4,
#  'what are the symptoms of prostate cancer?': 4,
#  'what causes dry mouth?': 4,
#  "what are the treatments for alzheimer's disease?": 4,
#  'what are the treatments for rheumatoid arthritis?': 4,
#  'what is (are) copd?': 4,
#  'what are the treatments for age-related macular degeneration?': 4,
#  'what is (are) depression?': 4,
#  'what are the symptoms of breast cancer?': 4,
#  'what are the treatments for colorectal cancer?': 4,
#  'what is (are) urinary incontinence?': 4,
#  'who is at risk for stroke?': 4,
#  'what is (are) prescription and illicit drug abuse?': 4,
#  'what are the symptoms of heart attack?': 4,
#  'who is at risk for heart attack?': 4,
#  'what are the treatments for skin cancer?': 4,
#  'what research (or clinical trials) is being done for skin cancer?': 4,
#  'what is (are) gout?': 4,
#  'what is (are) gum (periodontal) disease?': 4,
#  'how to diagnose heart failure?': 4,
#  'what is (are) polycythemia vera?': 4,
#  'what are the treatments for polycythemia vera?': 4,
#  'what is (are) ulcerative colitis?': 4,
#  'what is (are) gallstones?': 4,
#  'what is (are) alpha-1 antitrypsin deficiency?': 4,
#  'what is (are) hemophilia?': 4,
#  'what is (are) hemochromatosis?': 4,
#  'what is (are) rett syndrome?': 4,
#  'what is (are) tourette syndrome?': 4,
#  'what is (are) charcot-marie-tooth disease?': 4,
#  'what is (are) marfan syndrome?': 4,
#  'what is (are) multiple sclerosis?': 4,
#  'what is (are) tay-sachs disease?': 4,
#  "what is (are) cushing's syndrome?": 4,
#  'what is (are) gaucher disease?': 4,
#  'what is (are) alagille syndrome?': 4,
#  'what are the treatments for wilson disease?': 4,
#  'what is (are) narcolepsy?': 4,
#  'what are the treatments for narcolepsy?': 4,
#  'what is (are) restless legs syndrome?': 4,
#  'what is (are) primary hyperparathyroidism?': 4,
#  'what is (are) causes of diabetes?': 4,
#  'what to do for causes of diabetes?': 4,
#  'what is (are) urinary incontinence in men?': 4,
#  'what is (are) short bowel syndrome?': 4,
#  'what is (are) what i need to know about hepatitis b?': 4,
#  'what is (are) insulin resistance and prediabetes?': 4,
#  'what is (are) amyloidosis and kidney disease?': 4,
#  'what is (are) renal tubular acidosis?': 4,
#  'what is (are) nutrition for early chronic kidney disease in adults?': 4,
#  'what is (are) what i need to know about hepatitis c?': 4,
#  "what is (are) paget's disease of bone?": 3,
#  "what are the treatments for paget's disease of bone?": 3,
#  'what is (are) urinary tract infections?': 3,
#  'what is (are) osteoarthritis?': 3,
#  'what is (are) problems with taste?': 3,
#  'what causes problems with taste?': 3,
#  'how to prevent diabetes?': 3,
#  'what are the complications of knee replacement?': 3,
#  'how to prevent balance problems?': 3,
#  'what are the treatments for balance problems?': 3,
#  'what research (or clinical trials) is being done for prostate cancer?': 3,
#  'how to diagnose prostate cancer?': 3,
#  'what are the treatments for dry mouth?': 3,
#  'what are the treatments for osteoporosis?': 3,
#  "how to diagnose alzheimer's disease?": 3,
#  'how to prevent hearing loss?': 3,
#  'what is (are) low vision?': 3,
#  'what causes copd?': 3,
#  'what are the symptoms of copd?': 3,
#  'what are the symptoms of age-related macular degeneration?': 3,
#  'what are the symptoms of diabetic retinopathy?': 3,
#  'what are the treatments for depression?': 3,
#  'what is (are) problems with smell?': 3,
#  'what causes problems with smell?': 3,
#  'how to diagnose breast cancer?': 3,
#  'how to prevent breast cancer?': 3,
#  "what are the symptoms of parkinson's disease?": 3,
#  "what are the treatments for parkinson's disease?": 3,
#  "what research (or clinical trials) is being done for parkinson's disease?": 3,
#  'what causes lung cancer?': 3,
#  'what are the treatments for urinary incontinence?': 3,
#  'what are the symptoms of stroke?': 3,
#  'how to prevent stroke?': 3,
#  'what research (or clinical trials) is being done for stroke?': 3,
#  'what are the treatments for high blood cholesterol?': 3,
#  'what is (are) peripheral arterial disease (p.a.d.)?': 3,
#  'what are the symptoms of shingles?': 3,
#  'what are the treatments for shingles?': 3,
#  'what causes heart attack?': 3,
#  'how to diagnose heart attack?': 3,
#  'who is at risk for gout?': 3,
#  'what causes dry eye?': 3,
#  'what causes gum (periodontal) disease?': 3,
#  'what causes heart failure?': 3,
#  'who is at risk for heart failure?': 3,
#  'what are the symptoms of heart failure?': 3,
#  'what are the symptoms of polycythemia vera?': 3,
#  'who is at risk for testicular cancer?': 3,
#  'what is (are) myelodysplastic syndromes?': 3,
#  'who is at risk for oral cavity and oropharyngeal cancer?': 3,
#  'what is (are) endometrial cancer?': 3,
#  'who is at risk for endometrial cancer?': 3,
#  'what is (are) pituitary tumors?': 3,
#  'what is (are) ewing sarcoma?': 3,
#  'what is (are) langerhans cell histiocytosis?': 3,
#  'what are the treatments for langerhans cell histiocytosis?': 3,
#  "what is (are) bell's palsy?": 3,
#  'what is (are) asthma?': 3,
#  'what is (are) turner syndrome?': 3,
#  'what is (are) hypoglycemia?': 3,
#  "what is (are) crohn's disease?": 3,
#  'what is (are) chiari malformation?': 3,
#  'what is (are) spina bifida?': 3,
#  'what is (are) progressive supranuclear palsy?': 3,
#  'what is (are) prader-willi syndrome?': 3,
#  'what is (are) down syndrome?': 3,
#  'what is (are) ehlers-danlos syndrome?': 3,
#  'what is (are) ankylosing spondylitis?': 3,
#  'what is (are) neurofibromatosis?': 3,
#  'what is (are) complex regional pain syndrome?': 3,
#  'what is (are) bladder cancer?': 3,
#  'what is (are) fragile x syndrome?': 3,
#  'what is (are) myasthenia gravis?': 3,
#  'what is (are) sarcoidosis?': 3,
#  'what is (are) trigeminal neuralgia?': 3,
#  'what is (are) osteogenesis imperfecta?': 3,
#  'what is (are) sleep apnea?': 3,
#  'what is (are) cystic fibrosis?': 3,
#  'what is (are) creutzfeldt-jakob disease?': 3,
#  'what is (are) celiac disease?': 3,
#  'what is (are) spinal muscular atrophy?': 3,
#  'what is (are) kawasaki disease?': 3,
#  'what is (are) hyperthyroidism?': 3,
#  'what is (are) hypothyroidism?': 3,
#  'what is (are) ataxia telangiectasia?': 3,
#  'what is (are) muscular dystrophy?': 3,
#  'what is (are) amyotrophic lateral sclerosis?': 3,
#  'what is (are) thoracic outlet syndrome?': 3,
#  'what is (are) multiple system atrophy?': 3,
#  'what is (are) fabry disease?': 3,
#  'what are the treatments for fabry disease?': 3,
#  'what is (are) moebius syndrome?': 3,
#  'what is (are) intestinal pseudo-obstruction?': 3,
#  'what is (are) williams syndrome?': 3,
#  'what is (are) moyamoya disease?': 3,
#  'what are the treatments for moyamoya disease?': 3,
#  'what is (are) lennox-gastaut syndrome?': 3,
#  'what is (are) lupus nephritis?': 3,
#  'what is (are) angelman syndrome?': 3,
#  'what are the treatments for tourette syndrome?': 3,
#  'what is (are) essential tremor?': 3,
#  'what are the treatments for essential tremor?': 3,
#  'what is (are) giant axonal neuropathy?': 3,
#  "what is (are) graves' disease?": 3,
#  'what are the symptoms of polycystic kidney disease?': 3,
#  'what is (are) metachromatic leukodystrophy?': 3,
#  'what are the treatments for alpha-1 antitrypsin deficiency?': 3,
#  'what is (are) septo-optic dysplasia?': 3,
#  'what are the treatments for septo-optic dysplasia?': 3,
#  'what is (are) pelizaeus-merzbacher disease?': 3,
#  'what are the treatments for pelizaeus-merzbacher disease?': 3,
#  'what is (are) fanconi anemia?': 3,
#  'what is (are) joubert syndrome?': 3,
#  'what is (are) asperger syndrome?': 3,
#  'what is (are) anencephaly?': 3,
#  'what are the symptoms of hemochromatosis?': 3,
#  'what causes hemochromatosis?': 3,
#  'what is (are) sotos syndrome?': 3,
#  'what is (are) troyer syndrome?': 3,
#  'what are the treatments for troyer syndrome?': 3,
#  'what is (are) von willebrand disease?': 3,
#  'what are the treatments for tay-sachs disease?': 3,
#  'what are the treatments for restless legs syndrome?': 3,
#  'what is the outlook for electrocardiogram?': 3,
#  'what is (are) cyclic vomiting syndrome?': 3,
#  'what causes gas in the digestive tract?': 3,
#  "what are the treatments for adrenal insufficiency and addison's disease?": 3,
#  'what is (are) monogenic forms of diabetes: neonatal diabetes mellitus and maturity-onset diabetes of the young?': 3,
#  'what is (are) kidney stones in children?': 3,
#  'what causes what i need to know about erectile dysfunction?': 3,
#  'what are the treatments for what i need to know about diverticular disease?': 3,
#  'what is (are) prevent diabetes problems: keep your kidneys healthy?': 3,
#  "what are the treatments for kidney failure: choosing a treatment that's right for you?": 3,
#  'what is (are) what i need to know about kidney stones?': 3,
#  'what is (are) kidney stones in adults?': 3,
#  'what causes what i need to know about gas?': 3,
#  'what are the treatments for diabetes, heart disease, and stroke?': 3,
#  'what are the treatments for acromegaly?': 3,
#  'what is (are) fecal incontinence?': 3,
#  'what are the treatments for what i need to know about kidney failure and how its treated?': 3,
#  'what is (are) glomerular diseases?': 3,
#  'who is at risk for am i at risk for type 2 diabetes? taking steps to lower your risk of getting diabetes?': 3,
#  'what are the treatments for nerve disease and bladder control?': 3,
#  'how to diagnose what i need to know about gestational diabetes?': 3,
#  'what is (are) anemia in chronic kidney disease?': 3,
#  'what is (are) diabetic kidney disease?': 3,
#  'what is (are) diverticular disease?': 3,
#  'who is at risk for glaucoma?': 2,
#  'what causes high blood pressure?': 2,
#  'who is at risk for high blood pressure?': 2,
#  'what are the symptoms of high blood pressure?': 2,
#  'how to diagnose high blood pressure?': 2,
#  "what are the symptoms of paget's disease of bone?": 2,
#  "how to diagnose paget's disease of bone?": 2,
#  'what are the symptoms of urinary tract infections?': 2,
#  'how to prevent urinary tract infections?': 2,
#  'what causes osteoarthritis?': 2,
#  'what are the symptoms of osteoarthritis?': 2,
#  'what are the treatments for problems with taste?': 2,
#  'what research (or clinical trials) is being done for problems with taste?': 2,
#  'what are the treatments for anxiety disorders?': 2,
#  'who is at risk for diabetes?': 2,
#  'what are the symptoms of diabetes?': 2,
#  'what are the symptoms of balance problems?': 2,
#  'what causes balance problems?': 2,
#  'how many people are affected by prostate cancer?': 2,
#  'what are the symptoms of osteoporosis?': 2,
#  'how to diagnose osteoporosis?': 2,
#  'what are the symptoms of kidney disease?': 2,
#  'what research (or clinical trials) is being done for kidney disease?': 2,
#  "what causes alzheimer's disease?": 2,
#  'what causes rheumatoid arthritis?': 2,
#  'what are the symptoms of rheumatoid arthritis?': 2,
#  'how to diagnose rheumatoid arthritis?': 2,
#  'what is (are) hearing loss?': 2,
#  'what are the treatments for hearing loss?': 2,
#  'what causes low vision?': 2,
#  'how to prevent copd?': 2,
#  'how to diagnose copd?': 2,
#  'what are the treatments for copd?': 2,
#  'who is at risk for age-related macular degeneration?': 2,
#  'what causes diabetic retinopathy?': 2,
#  'what are the symptoms of depression?': 2,
#  'what are the symptoms of problems with smell?': 2,
#  'what are the treatments for problems with smell?': 2,
#  'what are the symptoms of colorectal cancer?': 2,
#  'what research (or clinical trials) is being done for colorectal cancer?': 2,
#  'how to prevent colorectal cancer?': 2,
#  "what causes parkinson's disease?": 2,
#  'who is at risk for leukemia?': 2,
#  'what are the symptoms of leukemia?': 2,
#  'what research (or clinical trials) is being done for leukemia?': 2,
#  'what are the symptoms of lung cancer?': 2,
#  'what causes urinary incontinence?': 2,
#  'how to diagnose urinary incontinence?': 2,
#  'how to diagnose stroke?': 2,
#  'what causes psoriasis?': 2,
#  'what research (or clinical trials) is being done for psoriasis?': 2,
#  'what causes high blood cholesterol?': 2,
#  'what are the symptoms of high blood cholesterol?': 2,
#  'how to diagnose high blood cholesterol?': 2,
#  'how to prevent peripheral arterial disease (p.a.d.)?': 2,
#  'what are the symptoms of peripheral arterial disease (p.a.d.)?': 2,
#  'how to diagnose peripheral arterial disease (p.a.d.)?': 2,
#  'what are the symptoms of prescription and illicit drug abuse?': 2,
#  'what are the symptoms of cataract?': 2,
#  'what are the treatments for cataract?': 2,
#  'how to diagnose creating a family health history?': 2,
#  'what causes shingles?': 2,
#  'how to prevent shingles?': 2,
#  'who is at risk for shingles?': 2,
#  'what are the symptoms of skin cancer?': 2,
#  'how to diagnose skin cancer?': 2,
#  'what causes gout?': 2,
#  'what are the symptoms of gout?': 2,
#  'what are the treatments for gout?': 2,
#  "how to diagnose alzheimer's caregiving?": 2,
#  "what to do for alzheimer's caregiving?": 2,
#  'what are the symptoms of dry eye?': 2,
#  'what are the treatments for dry eye?': 2,
#  'how to prevent gum (periodontal) disease?': 2,
#  'what are the symptoms of gum (periodontal) disease?': 2,
#  'how to prevent heart failure?': 2,
#  'what is the outlook for breast cancer?': 2,
#  'what are the stages of breast cancer?': 2,
#  'what is (are) hairy cell leukemia?': 2,
#  'what is (are) vulvar cancer?': 2,
#  'what is (are) gallbladder cancer?': 2,
#  'what is (are) anal cancer?': 2,
#  'how to diagnose polycythemia vera?': 2,
#  'what is (are) chronic myelogenous leukemia?': 2,
#  'what are the treatments for chronic myelogenous leukemia?': 2,
#  'what is (are) merkel cell carcinoma?': 2,
#  'what is (are) ovarian, fallopian tube, and primary peritoneal cancer?': 2,
#  'who is at risk for ovarian, fallopian tube, and primary peritoneal cancer?': 2,
#  'what is (are) liver (hepatocellular) cancer?': 2,
#  'who is at risk for liver (hepatocellular) cancer?': 2,
#  'what is (are) testicular cancer?': 2,
#  'what are the symptoms of juvenile myelomonocytic leukemia?': 2,
#  'what research (or clinical trials) is being done for endometrial cancer?': 2,
#  'what is (are) pancreatic cancer?': 2,
#  'what is (are) salivary gland cancer?': 2,
#  'who is at risk for neuroblastoma?': 2,
#  'is breast cancer inherited?': 2,
#  'what is (are) kaposi sarcoma?': 2,
#  'what is (are) chronic lymphocytic leukemia?': 2,
#  'what is (are) essential thrombocythemia?': 2,
#  'what are the treatments for essential thrombocythemia?': 2,
#  'what is the outlook for pituitary tumors?': 2,
#  'what are the treatments for pituitary tumors?': 2,
#  'what research (or clinical trials) is being done for pituitary tumors?': 2,
#  'is neuroblastoma inherited?': 2,
#  'what are the symptoms of neuroblastoma?': 2,
#  'what are the treatments for neuroblastoma?': 2,
#  'what is (are) male breast cancer?': 2,
#  'what is (are) primary myelofibrosis?': 2,
#  'what are the treatments for primary myelofibrosis?': 2,
#  'what is (are) melanoma?': 2,
#  'what is (are) retinoblastoma?': 2,
#  'is retinoblastoma inherited?': 2,
#  'what are the treatments for retinoblastoma?': 2,
#  'what are the symptoms of ewing sarcoma?': 2,
#  'what are the treatments for ewing sarcoma?': 2,
#  'what are the symptoms of langerhans cell histiocytosis?': 2,
#  'how to diagnose langerhans cell histiocytosis?': 2,
#  'what is (are) oxygen therapy?': 2,
#  "what is (are) huntington's disease?": 2,
#  'what is (are) tremor?': 2,
#  'what is (are) endocarditis?': 2,
#  'what is (are) von hippel-lindau disease?': 2,
#  'what is (are) pneumonia?': 2,
#  'what is (are) coma?': 2,
#  'what is (are) dwarfism?': 2,
#  'what is (are) vitiligo?': 2,
#  'what is (are) metabolic syndrome?': 2,
#  'what is (are) cat scratch disease?': 2,
#  'what is (are) aplastic anemia?': 2,
#  'what is (are) granulomatosis with polyangiitis?': 2,
#  'what is (are) transient ischemic attack?': 2,
#  'what is (are) deep vein thrombosis?': 2,
#  'what is (are) respiratory failure?': 2,
#  'what is (are) cirrhosis?': 2,
#  'what is (are) mitral valve prolapse?': 2,
#  'what is (are) diarrhea?': 2,
#  'what is (are) infectious arthritis?': 2,
#  'what is (are) hemorrhoids?': 2,
#  'what is (are) hidradenitis suppurativa?': 2,
#  'what is (are) swallowing disorders?': 2,
#  'what is (are) macular degeneration?': 2,
#  'what is (are) pulmonary hypertension?': 2,
#  'what is (are) carpal tunnel syndrome?': 2,
#  'what is (are) dementia?': 2,
#  'what is (are) cerebral palsy?': 2,
#  'what is (are) aphasia?': 2,
#  'what is (are) indigestion?': 2,
#  'what is (are) scleroderma?': 2,
#  'what is (are) thalassemia?': 2,
#  'what is (are) aspergillosis?': 2,
#  'what is (are) diabetic heart disease?': 2,
#  'what is (are) multiple myeloma?': 2,
#  'what is (are) cardiomyopathy?': 2,
#  'what is (are) tuberous sclerosis?': 2,
#  'what is (are) ovarian cancer?': 2,
#  'what is (are) phenylketonuria?': 2,
#  'what is (are) migraine?': 2,
#  'what is (are) guillain-barre syndrome?': 2,
#  'what is (are) varicose veins?': 2,
#  'what is (are) sudden infant death syndrome?': 2,
#  'what is (are) headache?': 2,
#  "what is (are) friedreich's ataxia?": 2,
#  'what is (are) cough?': 2,
#  'what is (are) atrial fibrillation?': 2,
#  'what is (are) traumatic brain injury?': 2,
#  'what is (are) carotid artery disease?': 2,
#  'what is (are) brachial plexus injuries?': 2,
#  'what is (are) usher syndrome?': 2,
#  'what is (are) pulmonary embolism?': 2,
#  'what is (are) interstitial cystitis?': 2,
#  'what is (are) rh incompatibility?': 2,
#  'what is (are) chronic pain?': 2,
#  'what is (are) lupus?': 2,
#  'what is (are) epilepsy?': 2,
#  'what is (are) arrhythmia?': 2,
#  'what is (are) back pain?': 2,
#  'what is (are) angina?': 2,
#  'what is (are) lyme disease?': 2,
#  'what is (are) malaria?': 2,
#  'what is (are) chronic fatigue syndrome?': 2,
#  'what is (are) psoriatic arthritis?': 2,
#  'what is (are) congenital heart defects?': 2,
#  'what is (are) syringomyelia?': 2,
#  'what is (are) rickets?': 2,
#  'what is (are) atherosclerosis?': 2,
#  'what is (are) hydrocephalus?': 2,
#  'what is (are) vasculitis?': 2,
#  'what is (are) insomnia?': 2,
#  'what is (are) anemia?': 2,
#  'what is (are) hereditary hemorrhagic telangiectasia?': 2,
#  'what are the treatments for hereditary hemorrhagic telangiectasia?': 2,
#  'what is (are) brooke-spiegler syndrome?': 2,
#  'what is (are) chorea-acanthocytosis?': 2,
#  'is chorea-acanthocytosis inherited?': 2,
#  'what are the treatments for chorea-acanthocytosis?': 2,
#  'what is (are) mowat-wilson syndrome?': 2,
#  'is mowat-wilson syndrome inherited?': 2,
#  "what are the treatments for bell's palsy?": 2,
#  'what is (are) factor v leiden thrombophilia?': 2,
#  'is factor v leiden thrombophilia inherited?': 2,
#  'what are the treatments for factor v leiden thrombophilia?': 2,
#  'what is (are) mucopolysaccharidosis type i?': 2,
#  'is mucopolysaccharidosis type i inherited?': 2,
#  'what are the treatments for mucopolysaccharidosis type i?': 2,
#  'what are the symptoms of asthma?': 2,
#  'what is (are) wolman disease?': 2,
#  'what are the treatments for wolman disease?': 2,
#  'what is (are) l1 syndrome?': 2,
#  'what is (are) androgen insensitivity syndrome?': 2,
#  'what is (are) periventricular heterotopia?': 2,
#  'what are the treatments for periventricular heterotopia?': 2,
#  'what is (are) vacterl association?': 2,
#  'what are the symptoms of alagille syndrome?': 2,
#  'what is (are) rabson-mendenhall syndrome?': 2,
#  'what is (are) 46,xx testicular disorder of sex development?': 2,
#  'what is (are) aniridia?': 2,
#  'what are the treatments for aniridia?': 2,
#  'what is (are) pseudoxanthoma elasticum?': 2,
#  'what are the treatments for pseudoxanthoma elasticum?': 2,
#  'what are the treatments for trigeminal neuralgia?': 2,
#  'what is (are) pachyonychia congenita?': 2,
#  'is pachyonychia congenita inherited?': 2,
#  'what are the treatments for pachyonychia congenita?': 2,
#  'what is (are) pendred syndrome?': 2,
#  'is pendred syndrome inherited?': 2,
#  'what is (are) cerebellar degeneration?': 2,
#  'what is (are) chordoma?': 2,
#  'what are the treatments for chordoma?': 2,
#  'what is (are) factor xiii deficiency?': 2,
#  'what are the treatments for factor xiii deficiency?': 2,
#  'what are the symptoms of wilson disease?': 2,
#  'what causes wilson disease?': 2,
#  'is wilson disease inherited?': 2,
#  'what is (are) galactosialidosis?': 2,
#  'is galactosialidosis inherited?': 2,
#  'what are the treatments for galactosialidosis?': 2,
#  'what is (are) russell-silver syndrome?': 2,
#  'is russell-silver syndrome inherited?': 2,
#  'what is (are) central core disease?': 2,
#  'what are the treatments for central core disease?': 2,
#  'what is (are) hereditary leiomyomatosis and renal cell cancer?': 2,
#  'is hereditary leiomyomatosis and renal cell cancer inherited?': 2,
#  'what are the treatments for hereditary leiomyomatosis and renal cell cancer?': 2,
#  'what is (are) beare-stevenson cutis gyrata syndrome?': 2,
#  'what is (are) townes-brocks syndrome?': 2,
#  'is townes-brocks syndrome inherited?': 2,
#  'what are the treatments for townes-brocks syndrome?': 2,
#  'what is (are) congenital sucrase-isomaltase deficiency?': 2,
#  'what are the treatments for congenital sucrase-isomaltase deficiency?': 2,
#  'what is (are) paget disease of bone?': 2,
#  'what is (are) spondylothoracic dysostosis?': 2,
#  'is spondylothoracic dysostosis inherited?': 2,
#  'what are the treatments for spondylothoracic dysostosis?': 2,
#  'what is (are) adolescent idiopathic scoliosis?': 2,
#  'is adolescent idiopathic scoliosis inherited?': 2,
#  'what are the treatments for adolescent idiopathic scoliosis?': 2,
#  'is fabry disease inherited?': 2,
#  'what is (are) andermann syndrome?': 2,
#  'what is (are) miller-dieker syndrome?': 2,
#  'what is (are) carnitine-acylcarnitine translocase deficiency?': 2,
#  'is carnitine-acylcarnitine translocase deficiency inherited?': 2,
#  'what are the treatments for carnitine-acylcarnitine translocase deficiency?': 2,
#  'what is (are) dentatorubral-pallidoluysian atrophy?': 2,
#  'is dentatorubral-pallidoluysian atrophy inherited?': 2,
#  'what are the treatments for dentatorubral-pallidoluysian atrophy?': 2,
#  'what is (are) cleidocranial dysplasia?': 2,
#  'is cleidocranial dysplasia inherited?': 2,
#  'what are the treatments for cleidocranial dysplasia?': 2,
#  'is rett syndrome inherited?': 2,
#  'is moebius syndrome inherited?': 2,
#  'what is (are) 48,xxyy syndrome?': 2,
#  'is 48,xxyy syndrome inherited?': 2,
#  'what is (are) renal tubular acidosis with deafness?': 2,
#  'what is (are) hypohidrotic ectodermal dysplasia?': 2,
#  'what are the treatments for hypohidrotic ectodermal dysplasia?': 2,
#  'is turner syndrome inherited?': 2,
#  'what is (are) paramyotonia congenita?': 2,
#  'what is (are) wolff-parkinson-white syndrome?': 2,
#  'is wolff-parkinson-white syndrome inherited?': 2,
#  'is williams syndrome inherited?': 2,
#  'what is (are) oculodentodigital dysplasia?': 2,
#  'what is (are) chops syndrome?': 2,
#  'what is (are) horizontal gaze palsy with progressive scoliosis?': 2,
#  'what is (are) bartter syndrome?': 2,
#  'is bartter syndrome inherited?': 2,
#  'what are the treatments for bartter syndrome?': 2,
#  'what causes nonalcoholic steatohepatitis?': 2,
#  'how to diagnose nonalcoholic steatohepatitis?': 2,
#  'what are the treatments for nonalcoholic steatohepatitis?': 2,
#  'what is (are) hereditary angioedema?': 2,
#  'what are the treatments for hereditary angioedema?': 2,
#  'what is (are) episodic ataxia?': 2,
#  'what is (are) partington syndrome?': 2,
#  'is partington syndrome inherited?': 2,
#  'what are the treatments for partington syndrome?': 2,
#  'what is (are) leukoencephalopathy with vanishing white matter?': 2,
#  'is leukoencephalopathy with vanishing white matter inherited?': 2,
#  'what are the treatments for leukoencephalopathy with vanishing white matter?': 2,
#  'what is (are) acromegaly?': 2,
#  'what are the symptoms of acromegaly?': 2,
#  'what is (are) donnai-barrow syndrome?': 2,
#  'what is (are) familial osteochondritis dissecans?': 2,
#  'what are the treatments for familial osteochondritis dissecans?': 2,
#  'what is (are) cohen syndrome?': 2,
#  'what are the treatments for cohen syndrome?': 2,
#  'what is (are) intrahepatic cholestasis of pregnancy?': 2,
#  'what are the treatments for intrahepatic cholestasis of pregnancy?': 2,
#  'what is (are) 17-beta hydroxysteroid dehydrogenase 3 deficiency?': 2,
#  'what is (are) brody myopathy?': 2,
#  'what are the treatments for brody myopathy?': 2,
#  'what is (are) miller syndrome?': 2,
#  'what is (are) gray platelet syndrome?': 2,
#  'what are the treatments for gray platelet syndrome?': 2,
#  'what is (are) pyruvate carboxylase deficiency?': 2,
#  'is pyruvate carboxylase deficiency inherited?': 2,
#  'what is (are) junctional epidermolysis bullosa?': 2,
#  'what is (are) hereditary sensory and autonomic neuropathy type v?': 2,
#  'what is (are) steatocystoma multiplex?': 2,
#  'what are the treatments for steatocystoma multiplex?': 2,
#  'what is (are) tetrahydrobiopterin deficiency?': 2,
#  'what is (are) primary spontaneous pneumothorax?': 2,
#  'what is (are) apert syndrome?': 2,
#  'what is (are) empty sella syndrome?': 2,
#  'what is (are) landau-kleffner syndrome?': 2,
#  'what is (are) norrie disease?': 2,
#  'what are the treatments for norrie disease?': 2,
#  'what is (are) floating-harbor syndrome?': 2,
#  'what are the treatments for floating-harbor syndrome?': 2,
#  'what is (are) isovaleric acidemia?': 2,
#  'is isovaleric acidemia inherited?': 2,
#  'what are the treatments for isovaleric acidemia?': 2,
#  'what is (are) homocystinuria?': 2,
#  'what is (are) q fever?': 2,
#  'what is (are) dihydropyrimidine dehydrogenase deficiency?': 2,
#  'is dihydropyrimidine dehydrogenase deficiency inherited?': 2,
#  'what are the treatments for dihydropyrimidine dehydrogenase deficiency?': 2,
#  'what is (are) choroideremia?': 2,
#  'what is (are) cardiofaciocutaneous syndrome?': 2,
#  'what are the treatments for cardiofaciocutaneous syndrome?': 2,
#  'what is (are) dermatomyositis?': 2,
#  'what are the treatments for dermatomyositis?': 2,
#  'what is (are) sturge-weber syndrome?': 2,
#  'what are the treatments for sturge-weber syndrome?': 2,
#  'what is (are) emanuel syndrome?': 2,
#  'what is (are) juvenile myoclonic epilepsy?': 2,
#  'is juvenile myoclonic epilepsy inherited?': 2,
#  'what are the treatments for juvenile myoclonic epilepsy?': 2,
#  'what is (are) ornithine transcarbamylase deficiency?': 2,
#  'is ornithine transcarbamylase deficiency inherited?': 2,
#  'what is (are) achondroplasia?': 2,
#  'is achondroplasia inherited?': 2,
#  'what are the treatments for achondroplasia?': 2,
#  'what is (are) mecp2 duplication syndrome?': 2,
#  'is mecp2 duplication syndrome inherited?': 2,
#  'what are the treatments for mecp2 duplication syndrome?': 2,
#  'what is (are) olivopontocerebellar atrophy?': 2,
#  'what is (are) erythromelalgia?': 2,
#  'what are the treatments for erythromelalgia?': 2,
#  'what is (are) x-linked adrenal hypoplasia congenita?': 2,
#  'is x-linked adrenal hypoplasia congenita inherited?': 2,
#  'what is (are) schizencephaly?': 2,
#  'what are the treatments for schizencephaly?': 2,
#  'what is (are) wolfram syndrome?': 2,
#  'is wolfram syndrome inherited?': 2,
#  'what are the treatments for wolfram syndrome?': 2,
#  'what is (are) focal dermal hypoplasia?': 2,
#  'is focal dermal hypoplasia inherited?': 2,
#  'what is (are) biotin-thiamine-responsive basal ganglia disease?': 2,
#  'what is (are) hypophosphatasia?': 2,
#  'is hypophosphatasia inherited?': 2,
#  'what are the treatments for hypophosphatasia?': 2,
#  'what is (are) glutaric acidemia type ii?': 2,
#  'what are the treatments for glutaric acidemia type ii?': 2,
#  'what is (are) neurofibromatosis type 1?': 2,
#  'is neurofibromatosis type 1 inherited?': 2,
#  'what are the treatments for neurofibromatosis type 1?': 2,
#  'what is (are) vohwinkel syndrome?': 2,
#  'what is (are) myofibrillar myopathy?': 2,
#  'is angelman syndrome inherited?': 2,
#  'what is (are) holt-oram syndrome?': 2,
#  'is holt-oram syndrome inherited?': 2,
#  'what are the treatments for holt-oram syndrome?': 2,
#  'what is (are) cap myopathy?': 2,
#  'what is (are) hermansky-pudlak syndrome?': 2,
#  'what is (are) retroperitoneal fibrosis?': 2,
#  'what are the treatments for retroperitoneal fibrosis?': 2,
#  'what is (are) friedreich ataxia?': 2,
#  'is friedreich ataxia inherited?': 2,
#  'what is (are) hypokalemic periodic paralysis?': 2,
#  'is hypokalemic periodic paralysis inherited?': 2,
#  'what is (are) herpes zoster oticus?': 2,
#  'what are the treatments for herpes zoster oticus?': 2,
#  'what is (are) pulmonary arterial hypertension?': 2,
#  'what are the treatments for pulmonary arterial hypertension?': 2,
#  'what is (are) porencephaly?': 2,
#  'what is (are) lymphedema-distichiasis syndrome?': 2,
#  'is tourette syndrome inherited?': 2,
#  'what is (are) maternally inherited diabetes and deafness?': 2,
#  'is maternally inherited diabetes and deafness inherited?': 2,
#  'what is (are) protein c deficiency?': 2,
#  'is protein c deficiency inherited?': 2,
#  'what are the treatments for protein c deficiency?': 2,
#  'what is (are) leukodystrophy?': 2,
#  'what is (are) snyder-robinson syndrome?': 2,
#  'is essential tremor inherited?': 2,
#  'what is (are) popliteal pterygium syndrome?': 2,
#  'what is (are) limb-girdle muscular dystrophy?': 2,
#  'is limb-girdle muscular dystrophy inherited?': 2,
#  'what are the treatments for limb-girdle muscular dystrophy?': 2,
#  'what is (are) danon disease?': 2,
#  'is danon disease inherited?': 2,
#  'what are the treatments for danon disease?': 2,
#  'what are the symptoms of sarcoidosis?': 2,
#  'what causes sarcoidosis?': 2,
#  'what are the treatments for sarcoidosis?': 2,
#  'what is (are) factor v deficiency?': 2,
#  'what are the treatments for factor v deficiency?': 2,
#  "what is (are) binswanger's disease?": 2,
#  "what are the treatments for binswanger's disease?": 2,
#  'what is (are) fibrodysplasia ossificans progressiva?': 2,
#  'is fibrodysplasia ossificans progressiva inherited?': 2,
#  'what are the treatments for fibrodysplasia ossificans progressiva?': 2,
#  'what are the treatments for creutzfeldt-jakob disease?': 2,
#  'what are the symptoms of autoimmune hepatitis?': 2,
#  'what causes autoimmune hepatitis?': 2,
#  'how to diagnose autoimmune hepatitis?': 2,
#  'what are the treatments for autoimmune hepatitis?': 2,
#  'what are the symptoms of marfan syndrome?': 2,
#  'is marfan syndrome inherited?': 2,
#  'what is (are) familial hemiplegic migraine?': 2,
#  'what is (are) huntington disease?': 2,
#  'is huntington disease inherited?': 2,
#  'what are the treatments for huntington disease?': 2,
#  'what are the treatments for down syndrome?': 2,
#  'what is (are) polymyositis?': 2,
#  'what are the treatments for polymyositis?': 2,
#  'what is (are) amelogenesis imperfecta?': 2,
#  'is amelogenesis imperfecta inherited?': 2,
#  'what are the treatments for amelogenesis imperfecta?': 2,
#  'what is (are) achondrogenesis?': 2,
#  'is achondrogenesis inherited?': 2,
#  'what is (are) inclusion body myositis?': 2,
#  'what is (are) harlequin ichthyosis?': 2,
#  'is harlequin ichthyosis inherited?': 2,
#  "what is (are) behcet's disease?": 2,
#  "what are the treatments for behcet's disease?": 2,
#  'is ankylosing spondylitis inherited?': 2,
#  'what are the treatments for ankylosing spondylitis?': 2,
#  'what is (are) multiple familial trichoepithelioma?': 2,
#  'is multiple familial trichoepithelioma inherited?': 2,
#  'what are the treatments for multiple familial trichoepithelioma?': 2,
#  'what is (are) lenz microphthalmia syndrome?': 2,
#  'what is (are) catecholaminergic polymorphic ventricular tachycardia?': 2,
#  'what are the treatments for catecholaminergic polymorphic ventricular tachycardia?': 2,
#  'what is (are) nonbullous congenital ichthyosiform erythroderma?': 2,
#  'what are the treatments for nonbullous congenital ichthyosiform erythroderma?': 2,
#  'what is (are) juvenile primary lateral sclerosis?': 2,
#  'is juvenile primary lateral sclerosis inherited?': 2,
#  "what is (are) farber's disease?": 2,
#  'what is (are) 22q13.3 deletion syndrome?': 2,
#  'what is (are) glutamate formiminotransferase deficiency?': 2,
#  'what is (are) isodicentric chromosome 15 syndrome?': 2,
#  'what is (are) tietz syndrome?': 2,
#  'what is (are) tumor necrosis factor receptor-associated periodic syndrome?': 2,
#  'is tumor necrosis factor receptor-associated periodic syndrome inherited?': 2,
#  'what are the treatments for tumor necrosis factor receptor-associated periodic syndrome?': 2,
#  'what is (are) klinefelter syndrome?': 2,
#  'is klinefelter syndrome inherited?': 2,
#  'what are the treatments for klinefelter syndrome?': 2,
#  'what is (are) lactate dehydrogenase deficiency?': 2,
#  'what is (are) majeed syndrome?': 2,
#  'is majeed syndrome inherited?': 2,
#  'what are the treatments for majeed syndrome?': 2,
#  'what is (are) dopa-responsive dystonia?': 2,
#  'is dopa-responsive dystonia inherited?': 2,
#  'is ehlers-danlos syndrome inherited?': 2,
#  'what are the treatments for ehlers-danlos syndrome?': 2,
#  'what is (are) maffucci syndrome?': 2,
#  'what are the treatments for maffucci syndrome?': 2,
#  'what is (are) tubular aggregate myopathy?': 2,
#  'is tubular aggregate myopathy inherited?': 2,
#  'what are the treatments for tubular aggregate myopathy?': 2,
#  'what is (are) thanatophoric dysplasia?': 2,
#  'is thanatophoric dysplasia inherited?': 2,
#  'what is (are) ellis-van creveld syndrome?': 2,
#  'what is (are) cowden syndrome?': 2,
#  'is cowden syndrome inherited?': 2,
#  'what are the treatments for cowden syndrome?': 2,
#  'what is (are) menkes disease?': 2,
#  'what is (are) isolated ectopia lentis?': 2,
#  'what is (are) neuroacanthocytosis?': 2,
#  'what are the treatments for neuroacanthocytosis?': 2,
#  "what are the symptoms of graves' disease?": 2,
#  'what is (are) polymicrogyria?': 2,
#  'what is (are) pseudoachondroplasia?': 2,
#  'is pseudoachondroplasia inherited?': 2,
#  'what is (are) complement component 2 deficiency?': 2,
#  'what is (are) glucose-6-phosphate dehydrogenase deficiency?': 2,
#  'is glucose-6-phosphate dehydrogenase deficiency inherited?': 2,
#  'what are the treatments for glucose-6-phosphate dehydrogenase deficiency?': 2,
#  'what is (are) baller-gerold syndrome?': 2,
#  'what is (are) succinic semialdehyde dehydrogenase deficiency?': 2,
#  'is succinic semialdehyde dehydrogenase deficiency inherited?': 2,
#  'what are the treatments for succinic semialdehyde dehydrogenase deficiency?': 2,
#  'what is (are) nicolaides-baraitser syndrome?': 2,
#  'is nicolaides-baraitser syndrome inherited?': 2,
#  'what is (are) combined malonic and methylmalonic aciduria?': 2,
#  'what is (are) alport syndrome?': 2,
#  'is alport syndrome inherited?': 2,
#  'what are the treatments for alport syndrome?': 2,
#  'what is (are) lysinuric protein intolerance?': 2,
#  'what is (are) tetra-amelia syndrome?': 2,
#  'what is (are) warfarin sensitivity?': 2,
#  'what is (are) myhre syndrome?': 2,
#  'is myhre syndrome inherited?': 2,
#  'what are the treatments for myhre syndrome?': 2,
#  'what is (are) rotor syndrome?': 2,
#  'what are the treatments for rotor syndrome?': 2,
#  'what is (are) nemaline myopathy?': 2,
#  'what is (are) leber hereditary optic neuropathy?': 2,
#  'is leber hereditary optic neuropathy inherited?': 2,
#  'what is (are) congenital hepatic fibrosis?': 2,
#  'what is (are) multiple epiphyseal dysplasia?': 2,
#  'is multiple epiphyseal dysplasia inherited?': 2,
#  'what is (are) familial exudative vitreoretinopathy?': 2,
#  'is familial exudative vitreoretinopathy inherited?': 2,
#  'what are the treatments for familial exudative vitreoretinopathy?': 2,
#  'what is (are) centronuclear myopathy?': 2,
#  'what is (are) inclusion body myopathy 2?': 2,
#  'is inclusion body myopathy 2 inherited?': 2,
#  'what are the treatments for inclusion body myopathy 2?': 2,
#  'what is (are) greig cephalopolysyndactyly syndrome?': 2,
#  'is greig cephalopolysyndactyly syndrome inherited?': 2,
#  'what are the treatments for greig cephalopolysyndactyly syndrome?': 2,
#  'what is (are) char syndrome?': 2,
#  'what is (are) cerebral autosomal recessive arteriopathy with subcortical infarcts and leukoencephalopathy?': 2,
#  'what is (are) unverricht-lundborg disease?': 2,
#  'what is (are) coffin-siris syndrome?': 2,
#  'what are the treatments for coffin-siris syndrome?': 2,
#  'what is (are) lujan syndrome?': 2,
#  'what is (are) microcephaly?': 2,
#  'what is (are) primary lateral sclerosis?': 2,
#  'what is (are) cadasil?': 2,
#  'what are the treatments for cadasil?': 2,
#  'what is (are) dravet syndrome?': 2,
#  'what is (are) adcy5-related dyskinesia?': 2,
#  'what is (are) congenital central hypoventilation syndrome?': 2,
#  'is congenital central hypoventilation syndrome inherited?': 2,
#  'what is (are) peutz-jeghers syndrome?': 2,
#  'is peutz-jeghers syndrome inherited?': 2,
#  'what is (are) pulmonary alveolar microlithiasis?': 2,
#  'what is (are) laing distal myopathy?': 2,
#  'what is (are) dystrophic epidermolysis bullosa?': 2,
#  'what is (are) fryns syndrome?': 2,
#  'is fryns syndrome inherited?': 2,
#  'is metachromatic leukodystrophy inherited?': 2,
#  'what is (are) x-linked sideroblastic anemia?': 2,
#  'what is (are) hypochondroplasia?': 2,
#  'what are the treatments for hypochondroplasia?': 2,
#  'what is (are) hepatic lipase deficiency?': 2,
#  'what are the symptoms of alpha-1 antitrypsin deficiency?': 2,
#  'what causes alpha-1 antitrypsin deficiency?': 2,
#  'how to diagnose alpha-1 antitrypsin deficiency?': 2,
#  'what is (are) parkes weber syndrome?': 2,
#  'what are the treatments for parkes weber syndrome?': 2,
#  'is osteogenesis imperfecta inherited?': 2,
#  'what is (are) brown-sequard syndrome?': 2,
#  'what are the treatments for brown-sequard syndrome?': 2,
#  'what is (are) carpenter syndrome?': 2,
#  'what is (are) meesmann corneal dystrophy?': 2,
#  'what are the treatments for meesmann corneal dystrophy?': 2,
#  'what is (are) milroy disease?': 2,
#  'is milroy disease inherited?': 2,
#  'what are the treatments for milroy disease?': 2,
#  'what is (are) facioscapulohumeral muscular dystrophy?': 2,
#  'what is (are) permanent neonatal diabetes mellitus?': 2,
#  'what is (are) poland syndrome?': 2,
#  'is poland syndrome inherited?': 2,
#  'what are the treatments for poland syndrome?': 2,
#  'what is (are) neutral lipid storage disease with myopathy?': 2,
#  'is neutral lipid storage disease with myopathy inherited?': 2,
#  'what are the treatments for neutral lipid storage disease with myopathy?': 2,
#  'what is (are) glutaric acidemia type i?': 2,
#  'is glutaric acidemia type i inherited?': 2,
#  'what is (are) mandibulofacial dysostosis with microcephaly?': 2,
#  'is mandibulofacial dysostosis with microcephaly inherited?': 2,
#  'what are the treatments for mandibulofacial dysostosis with microcephaly?': 2,
#  'what is (are) wagr syndrome?': 2,
#  'what is (are) autosomal dominant nocturnal frontal lobe epilepsy?': 2,
#  'is septo-optic dysplasia inherited?': 2,
#  'what is (are) glanzmann thrombasthenia?': 2,
#  'what are the symptoms of narcolepsy?': 2,
#  'how to diagnose narcolepsy?': 2,
#  'what is (are) hereditary neuralgic amyotrophy?': 2,
#  'what is (are) multiple endocrine neoplasia type 1?': 2,
#  'what is (are) congenital mirror movement disorder?': 2,
#  'what is (are) hereditary multiple osteochondromas?': 2,
#  'is hereditary multiple osteochondromas inherited?': 2,
#  'what are the treatments for hereditary multiple osteochondromas?': 2,
#  'is pelizaeus-merzbacher disease inherited?': 2,
#  'what is (are) fg syndrome?': 2,
#  'what are the treatments for fg syndrome?': 2,
#  'what is (are) treacher collins syndrome?': 2,
#  'what are the treatments for treacher collins syndrome?': 2,
#  'what is (are) larsen syndrome?': 2,
#  'is larsen syndrome inherited?': 2,
#  'what is (are) progressive multifocal leukoencephalopathy?': 2,
#  'what are the treatments for progressive multifocal leukoencephalopathy?': 2,
#  'what is (are) noonan syndrome?': 2,
#  'is noonan syndrome inherited?': 2,
#  'what are the treatments for noonan syndrome?': 2,
#  'what is (are) loeys-dietz syndrome?': 2,
#  'what is (are) cockayne syndrome?': 2,
#  'what is (are) trisomy 18?': 2,
#  'is trisomy 18 inherited?': 2,
#  'what is (are) cherubism?': 2,
#  'is cherubism inherited?': 2,
#  'what is (are) paroxysmal nocturnal hemoglobinuria?': 2,
#  'what is (are) oculofaciocardiodental syndrome?': 2,
#  'what are the symptoms of fanconi anemia?': 2,
#  'what is (are) globozoospermia?': 2,
#  'what is (are) ollier disease?': 2,
#  'what are the treatments for ollier disease?': 2,
#  'is fragile x syndrome inherited?': 2,
#  'what are the treatments for fragile x syndrome?': 2,
#  'what is (are) 2-methylbutyryl-coa dehydrogenase deficiency?': 2,
#  'what is (are) nail-patella syndrome?': 2,
#  'what is (are) 21-hydroxylase deficiency?': 2,
#  'is 21-hydroxylase deficiency inherited?': 2,
#  'what are the treatments for 21-hydroxylase deficiency?': 2,
#  'what is (are) arginase deficiency?': 2,
#  'what are the treatments for arginase deficiency?': 2,
#  'what is (are) cushing disease?': 2,
#  'what is (are) familial mediterranean fever?': 2,
#  'is familial mediterranean fever inherited?': 2,
#  'what are the treatments for familial mediterranean fever?': 2,
#  'what is (are) pyruvate dehydrogenase deficiency?': 2,
#  'is pyruvate dehydrogenase deficiency inherited?': 2,
#  'what are the treatments for pyruvate dehydrogenase deficiency?': 2,
#  'what is (are) kallmann syndrome?': 2,
#  'is kallmann syndrome inherited?': 2,
#  'what is (are) congenital diaphragmatic hernia?': 2,
#  'what is (are) congenital contractural arachnodactyly?': 2,
#  'is congenital contractural arachnodactyly inherited?': 2,
#  'what are the treatments for congenital contractural arachnodactyly?': 2,
#  'what is (are) opitz g/bbb syndrome?': 2,
#  'is opitz g/bbb syndrome inherited?': 2,
#  'what are the treatments for opitz g/bbb syndrome?': 2,
#  'what is (are) pallister-killian mosaic syndrome?': 2,
#  'is joubert syndrome inherited?': 2,
#  'what is (are) frontonasal dysplasia?': 2,
#  'is amyotrophic lateral sclerosis inherited?': 2,
#  'what are the treatments for amyotrophic lateral sclerosis?': 2,
#  'what is (are) familial hypertrophic cardiomyopathy?': 2,
#  'is familial hypertrophic cardiomyopathy inherited?': 2,
#  'what is (are) alzheimer disease?': 2,
#  'what is (are) gracile syndrome?': 2,
#  'what is (are) triple a syndrome?': 2,
#  'is triple a syndrome inherited?': 2,
#  'what are the treatments for triple a syndrome?': 2,
#  'what is (are) spondylocarpotarsal synostosis syndrome?': 2,
#  'is asperger syndrome inherited?': 2,
#  'what is (are) hereditary fructose intolerance?': 2,
#  'is hereditary fructose intolerance inherited?': 2,
#  'what are the treatments for hereditary fructose intolerance?': 2,
#  'what is (are) autosomal dominant partial epilepsy with auditory features?': 2,
#  'what is (are) guanidinoacetate methyltransferase deficiency?': 2,
#  'is anencephaly inherited?': 2,
#  'what is (are) gerstmann-straussler-scheinker disease?': 2,
#  'what are the treatments for gerstmann-straussler-scheinker disease?': 2,
#  'what is (are) lamellar ichthyosis?': 2,
#  'what are the treatments for lamellar ichthyosis?': 2,
#  'what is (are) adiposis dolorosa?': 2,
#  'is adiposis dolorosa inherited?': 2,
#  'what are the treatments for adiposis dolorosa?': 2,
#  'what is (are) potocki-shaffer syndrome?': 2,
#  'what are the treatments for potocki-shaffer syndrome?': 2,
#  'what is (are) hereditary angiopathy with nephropathy, aneurysms, and muscle cramps syndrome?': 2,
#  'what are the treatments for hereditary angiopathy with nephropathy, aneurysms, and muscle cramps syndrome?': 2,
#  'what is (are) cornelia de lange syndrome?': 2,
#  'is cornelia de lange syndrome inherited?': 2,
#  'what are the treatments for cornelia de lange syndrome?': 2,
#  'what is (are) tetralogy of fallot?': 2,
#  'what are the symptoms of tetralogy of fallot?': 2,
#  'what is (are) x-linked creatine deficiency?': 2,
#  'what is (are) cerebrotendinous xanthomatosis?': 2,
#  'what are the treatments for cerebrotendinous xanthomatosis?': 2,
#  'what is (are) x-linked congenital stationary night blindness?': 2,
#  'what is (are) congenital myasthenic syndrome?': 2,
#  'is congenital myasthenic syndrome inherited?': 2,
#  'what is (are) gm1 gangliosidosis?': 2,
#  'is gm1 gangliosidosis inherited?': 2,
#  'what are the treatments for gm1 gangliosidosis?': 2,
#  'what is (are) arts syndrome?': 2,
#  'is arts syndrome inherited?': 2,
#  'what is (are) abetalipoproteinemia?': 2,
#  'is abetalipoproteinemia inherited?': 2,
#  'what are the treatments for abetalipoproteinemia?': 2,
#  'what is (are) 22q11.2 deletion syndrome?': 2,
#  'is 22q11.2 deletion syndrome inherited?': 2,
#  'what is (are) robinow syndrome?': 2,
#  'is robinow syndrome inherited?': 2,
#  'what is (are) pseudohypoaldosteronism type 2?': 2,
#  'what are the treatments for pseudohypoaldosteronism type 2?': 2,
#  'what is (are) carney complex?': 2,
#  'what is (are) pantothenate kinase-associated neurodegeneration?': 2,
#  'what are the treatments for pantothenate kinase-associated neurodegeneration?': 2,
#  'what is (are) erdheim-chester disease?': 2,
#  'is sotos syndrome inherited?': 2,
#  'what is (are) frontotemporal dementia?': 2,
#  'what is (are) costello syndrome?': 2,
#  'what is (are) lynch syndrome?': 2,
#  'is lynch syndrome inherited?': 2,
#  'what is (are) colpocephaly?': 2,
#  'what are the treatments for colpocephaly?': 2,
#  'what is (are) biotinidase deficiency?': 2,
#  'is troyer syndrome inherited?': 2,
#  'what is (are) hennekam syndrome?': 2,
#  'what are the symptoms of von willebrand disease?': 2,
#  'what causes von willebrand disease?': 2,
#  'is von willebrand disease inherited?': 2,
#  'is ewing sarcoma inherited?': 2,
#  'what is (are) laron syndrome?': 2,
#  'is laron syndrome inherited?': 2,
#  'what are the treatments for laron syndrome?': 2,
#  ...}

# %% [markdown]
# ### Find out minimum and maximum number of words in an answer.
# This code also checks for questions with empty answer strings and with only less than 10 words for a single answer.

# %%
q_to_word_counts = {}
min_q_to_word_counts = {}
min_word = 999999
max_word = 0


for question, answers in clean_q_to_a.items():
    word_count = [len(answer.split()) for answer in answers]
    if len(word_count)==0: # empty list of words
        min_q_to_word_counts[question] = [0]
        continue
    elif len(word_count)==1 and word_count[0]<10: # only single answer with less than 10 words.
        min_q_to_word_counts[question] = word_count 
        continue
    min_word = min(min_word, min(word_count))
    max_word = max(max_word, max(word_count))
    q_to_word_counts[question] = word_count

# %%
print('Minimum words: ', min_word)
print('Maximum words: ', max_word)
# Out:
# Minimum words:  4
# Maximum words:  4188

# %%
min_q_to_word_counts # display all questions with single answers having less than 10 words.
# Out:
# {'what causes childhood brain stem glioma?': [9],
#  'what causes childhood ependymoma?': [9],
#  "what are the symptoms of bell's palsy?": [7],
#  "what causes bell's palsy?": [4],
#  'what are the treatments for epidermolysis bullosa acquisita?': [7],
#  'what are the treatments for progressive hemifacial atrophy?': [7],
#  'how to diagnose occipital horn syndrome?': [8],
#  'what is (are) parasites - toxocariasis (also known as roundworm infection)?': [6],
#  'what can i do to prevent poisoning by marine toxins?': [6],
#  'how to prevent acanthamoeba - granulomatous amebic encephalitis (gae); keratitis?': [1],
#  'what is (are) parasites - african trypanosomiasis (also known as sleeping sickness)?': [4],
#  'what is (are) parasites - paragonimiasis (also known as paragonimus infection)?': [4],
#  'what is (are) parasites - lymphatic filariasis?': [6],
#  'what is the outlook for thyrotoxic myopathy?': [9],
#  'what is the outlook for agnosia?': [6],
#  'how many people are affected by hirschsprung disease?': [9],
#  'how many people are affected by erythromelalgia?': [6],
#  'how many people are affected by congenital diaphragmatic hernia?': [9],
#  'how many people are affected by tyrosine hydroxylase deficiency?': [7],
#  'how many people are affected by hypomyelination and congenital cataract?': [9],
#  'how many people are affected by progressive external ophthalmoplegia?': [8],
#  'how many people are affected by esophageal atresia/tracheoesophageal fistula?': [9],
#  'how many people are affected by microphthalmia?': [8],
#  'how many people are affected by rett syndrome?': [9],
#  'how many people are affected by treacher collins syndrome?': [9],
#  'how many people are affected by rippling muscle disease?': [8],
#  'how many people are affected by aminoacylase 1 deficiency?': [8],
#  'how many people are affected by tuberous sclerosis complex?': [9],
#  'how many people are affected by ppm-x syndrome?': [7],
#  'how many people are affected by blepharophimosis, ptosis, and epicanthus inversus syndrome?': [6],
#  'how many people are affected by pallister-hall syndrome?': [9],
#  'how many people are affected by activated pi3k-delta syndrome?': [8],
#  'how many people are affected by multiple pterygium syndrome?': [8],
#  'how many people are affected by swyer syndrome?': [9],
#  'how many people are affected by familial isolated hyperparathyroidism?': [8],
#  'how many people are affected by horizontal gaze palsy with progressive scoliosis?': [9],
#  'how many people are affected by spinocerebellar ataxia type 1?': [9],
#  'how many people are affected by piebaldism?': [6],
#  'how many people are affected by hystrix-like ichthyosis with deafness?': [9],
#  'how many people are affected by erythrokeratodermia variabilis et progressiva?': [9],
#  'how many people are affected by cystinuria?': [7],
#  'how many people are affected by myostatin-related muscle hypertrophy?': [7],
#  'how many people are affected by small fiber neuropathy?': [8],
#  'how many people are affected by alport syndrome?': [9],
#  'how many people are affected by monilethrix?': [6],
#  'how many people are affected by autosomal recessive congenital methemoglobinemia?': [9],
#  'how many people are affected by larsen syndrome?': [9],
#  'how many people are affected by kabuki syndrome?': [9],
#  'how many people are affected by familial glucocorticoid deficiency?': [8],
#  'how many people are affected by epidermal nevus?': [8],
#  'how many people are affected by ataxia neuropathy spectrum?': [8],
#  'how many people are affected by x-linked agammaglobulinemia?': [8],
#  'how many people are affected by methemoglobinemia, beta-globin type?': [8],
#  'how many people are affected by childhood myocerebrohepatopathy spectrum?': [8],
#  'how many people are affected by autosomal recessive hyper-ige syndrome?': [9],
#  'how many people are affected by catsper1-related nonsyndromic male infertility?': [9],
#  'how many people are affected by myofibrillar myopathy?': [7],
#  'how many people are affected by mayer-rokitansky-kster-hauser syndrome?': [9],
#  'how many people are affected by supravalvular aortic stenosis?': [8],
#  'how many people are affected by greig cephalopolysyndactyly syndrome?': [9],
#  'how many people are affected by hyperlysinemia?': [6],
#  'how many people are affected by argininosuccinic aciduria?': [9],
#  'how many people are affected by isolated lissencephaly sequence?': [7],
#  'how many people are affected by pfeiffer syndrome?': [8],
#  "how to prevent peyronie's disease?": [9],
#  'what causes what i need to know about bladder control for women?': [6]}

# %% [markdown]
# ### Removing questions with non-informative single answers.

# %%
final_clean_q_to_a = {}

for question, answers in clean_q_to_a.items():
    word_count = [len(answer.split()) for answer in answers]
    if len(word_count)<1 or (len(word_count)==1 and word_count[0]<5):
        print(question, answers) # non informative answers
        continue
    final_clean_q_to_a[question] = answers

len(final_clean_q_to_a)
# Out:
# what causes bell's palsy? ["What causes Bell's palsy?"]
# how to prevent acanthamoeba - granulomatous amebic encephalitis (gae); keratitis? ['Topics']
# what is (are) parasites - african trypanosomiasis (also known as sleeping sickness)? ['Frequently Asked Queestions (FAQs)']
# what is (are) parasites - paragonimiasis (also known as paragonimus infection)? ['Frequently Asked Queestions (FAQs)']
# 14338

# %% [markdown]
# ## Observations:
# 1. In some cases, the question is present as a part of the answer.
# 2. Found multiple cases where the answers have less than 6 words.
# 3. Most of those cases with less than 6 words, have no actual informative content.

# %% [markdown]
# ### Save clean question to answers dictionary map

# %%
file_path = 'clean_questions_to_answers_dataset_v1.json'
write_json(file_path, final_clean_q_to_a)
